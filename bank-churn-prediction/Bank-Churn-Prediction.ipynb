# %% [markdown]
# <center><font size=6> Bank Churn Prediction </font></center>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context

# %% [markdown]
# Businesses like banks which provide service have to worry about problem of 'Customer Churn' i.e. customers leaving and joining another service provider. It is important to understand which aspects of the service influence a customer's decision in this regard. Management can concentrate efforts on improvement of service, keeping in mind these priorities.

# %% [markdown]
# ### Objective

# %% [markdown]
# You as a Data scientist with the  bank need to  build a neural network based classifier that can determine whether a customer will leave the bank  or not in the next 6 months.

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# * CustomerId: Unique ID which is assigned to each customer
#
# * Surname: Last name of the customer
#
# * CreditScore: It defines the credit history of the customer.
#
# * Geography: A customer’s location
#
# * Gender: It defines the Gender of the customer
#
# * Age: Age of the customer
#
# * Tenure: Number of years for which the customer has been with the bank
#
# * NumOfProducts: refers to the number of products that a customer has purchased through the bank.
#
# * Balance: Account balance
#
# * HasCrCard: It is a categorical variable which decides whether the customer has credit card or not.
#
# * EstimatedSalary: Estimated salary
#
# * isActiveMember: Is is a categorical variable which decides whether the customer is active member of the bank or not ( Active member in the sense, using bank products regularly, making transactions etc )
#
# * Exited : whether or not the customer left the bank within six month. It can take two values
# ** 0=No ( Customer did not leave the bank )
# ** 1=Yes ( Customer left the bank )

# %% [markdown]
# ## Importing necessary libraries

# %%
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# Libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Library to split data
from sklearn.model_selection import train_test_split

# Library to import to standardize the data
from sklearn.preprocessing import StandardScaler, LabelEncoder

# Importing different functions to build models
import tensorflow as tf
from tensorflow import keras
from keras import backend
from keras.models import Sequential
from keras.layers import Dense, Dropout

# Importing SMOTE
from imblearn.over_sampling import SMOTE

# Importing metrics
from sklearn.metrics import confusion_matrix,roc_curve,classification_report,recall_score

import random

# Library to avoid the warnings
import warnings
warnings.filterwarnings("ignore")

## Google colab library to access Google Drive.
#from google.colab import drive
#drive.mount('/content/drive/')

# %% [markdown]
# ## Define Functions

# %% [markdown]
# #### EDA Functions

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to the show density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a triangle will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %%
# function to plot stacked bar chart

def stacked_barplot(data, predictor, target, n=None):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )

    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left", frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %%
### Function to plot distributions

def distribution_plot_wrt_target(data, predictor, target):

    fig, axs = plt.subplots(2, 2, figsize=(12, 10))

    target_uniq = data[target].unique()

    axs[0, 0].set_title("Distribution of target for target=" + str(target_uniq[0]))
    sns.histplot(
        data=data[data[target] == target_uniq[0]],
        x=predictor,
        kde=True,
        ax=axs[0, 0],
        color="teal",
    )

    axs[0, 1].set_title("Distribution of target for target=" + str(target_uniq[1]))
    sns.histplot(
        data=data[data[target] == target_uniq[1]],
        x=predictor,
        kde=True,
        ax=axs[0, 1],
        color="orange",
    )

    axs[1, 0].set_title("Boxplot w.r.t target")
    sns.boxplot(data=data, x=target, y=predictor, ax=axs[1, 0], palette="gist_rainbow")

    axs[1, 1].set_title("Boxplot (without outliers) w.r.t target")
    sns.boxplot(
        data=data,
        x=target,
        y=predictor,
        ax=axs[1, 1],
        showfliers=False,
        palette="gist_rainbow",
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Pre-processing Functions

# %%
def outlier_detection(data):
  Q1 = data.quantile(0.25)  # To find the 25th percentile
  Q3 = data.quantile(0.75)  # To find the 75th percentile

  IQR = Q3 - Q1  # Inter Quantile Range (75th perentile - 25th percentile)

  # Finding lower and upper bounds for all values. All values outside these bounds are outliers
  lower = (Q1 - 1.5 * IQR)
  upper = (Q3 + 1.5 * IQR)

  # checking the % outliers
  print(((data.select_dtypes(include=["float64", "int64"]) < lower) | (data.select_dtypes(include=["float64", "int64"]) > upper)).sum() / len(data) * 100)

# %%
## Function to inverse encoding
def inverse_mapping(x, y):
    inv_dict = {v: k for k, v in x.items()}
    X_train[y] = np.round(X_train[y]).map(inv_dict).astype("category")
    X_val[y] = np.round(X_val[y]).map(inv_dict).astype("category")
    X_test[y] = np.round(X_test[y]).map(inv_dict).astype("category")

# %% [markdown]
# ### Model Performance Metrics

# %%
## Function to create confusion matrix
def make_confusion_matrix(model,y_actual,labels=[1, 0]):
    '''
    model : classifier to predict values of X
    y_actual : ground truth

    '''
    y_predict = model.predict(X_test)
    cm=metrics.confusion_matrix( y_actual, y_predict, labels=[0, 1])
    df_cm = pd.DataFrame(cm, index = [i for i in ["Actual - No","Actual - Yes"]],
                  columns = [i for i in ['Predicted - No','Predicted - Yes']])
    group_counts = ["{0:0.0f}".format(value) for value in
                cm.flatten()]
    group_percentages = ["{0:.2%}".format(value) for value in
                         cm.flatten()/np.sum(cm)]
    labels = [f"{v1}\n{v2}" for v1, v2 in
              zip(group_counts,group_percentages)]
    labels = np.asarray(labels).reshape(2,2)
    plt.figure(figsize = (10,7))
    sns.heatmap(df_cm, annot=labels,fmt='')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# defining a function to compute different metrics to check performance of a classification model built using sklearn
def model_performance_classification_sklearn(model, predictors, target):
    """
    Function to compute different metrics to check classification model performance

    model: classifier
    predictors: independent variables
    target: dependent variable
    """

    # predicting using the independent variables
    pred = model.predict(predictors)

    acc = accuracy_score(target, pred)  # to compute Accuracy
    recall = recall_score(target, pred)  # to compute Recall
    precision = precision_score(target, pred)  # to compute Precision
    f1 = f1_score(target, pred)  # to compute F1-score

    # creating a dataframe of metrics
    df_perf = pd.DataFrame(
        {
            "Accuracy": acc,
            "Recall": recall,
            "Precision": precision,
            "F1": f1

        },
        index=[0],
    )

    return df_perf

# %% [markdown]
# ## Loading the dataset

# %%
# Use pandas to load the csv file
churn_df = pd.read_csv("https://raw.githubusercontent.com/todd-wilson/portfolio/main/bank-churn-prediction/data/bank-churn.csv")
# Copy the original data frame
df = churn_df.copy()

# %% [markdown]
# ## Data Overview

# %% [markdown]
# ### First and Last Rows

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# #### Observations
# * Geography and Gender are categorical and will need to be treated.
# * CustomerId and RowNumber are unique identifiers and will be dropped.
# * Surname is a text column and will be dropped as I don't believe it is a good independent variable for bank churn.

# %% [markdown]
# ### Data Summary

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# #### Observations
# * There are 10,000 rows and 14 columns.
# * Geography and Gender are object data types and will need to be treated.

# %% [markdown]
# #### Stat Summary

# %%
df.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# CustomerId       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# CreditScore           584.00  6.520000e+02  7.180000e+02       850.00
# Age                    32.00  3.700000e+01  4.400000e+01        92.00
# Tenure                  3.00  5.000000e+00  7.000000e+00        10.00
# Balance                 0.00  9.719854e+04  1.276442e+05    250898.09
# NumOfProducts           1.00  1.000000e+00  2.000000e+00         4.00
# HasCrCard               0.00  1.000000e+00  1.000000e+00         1.00
# IsActiveMember          0.00  1.000000e+00  1.000000e+00         1.00
# EstimatedSalary     51002.11  1.001939e+05  1.493882e+05    199992.48
# Exited                  0.00  0.000000e+00  0.000000e+00         1.00

# %% [markdown]
# ##### Observations
# * Estimated salary min of $11.50 is definitely an outlier.
# * Oldest customer is 92 and youngest is 18.
# * Nothing out of the ordinary.

# %% [markdown]
# ### Drop Columns

# %% [markdown]
# * Surname is an identifier which would not be a good independent variable so it will be dropped.
# * RowNumber and CustomerId are unique identifiers and will be dropped.

# %%
# Dropping columns
df = df.drop(['Surname', 'RowNumber', 'CustomerId'], axis=1)

# Verify the columns are gone.
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %% [markdown]
# ### Duplicates and Nulls

# %%
df.duplicated().sum()
# Out:
# 0

# %%
round(df.isnull().sum() / df.isnull().count() * 100, 2)
# Out:
# CreditScore        0.0
# Geography          0.0
# Gender             0.0
# Age                0.0
# Tenure             0.0
# Balance            0.0
# NumOfProducts      0.0
# HasCrCard          0.0
# IsActiveMember     0.0
# EstimatedSalary    0.0
# Exited             0.0
# dtype: float64

# %% [markdown]
# #### Observations
# * There are no duplicated rows.
# * There are no NULL values.

# %% [markdown]
# ### Column Value Analysis

# %%
# list all the unique values in the columsn to see if there is any dirty data
for col in df.columns:
  print(f'{col}: ', df[col].unique())
# Out:
# CreditScore:  [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
#  681 544 696 766 727 693 557 531 498 651 791 733 811 707 714 782 775 799
#  602 744 588 747 583 627 731 629 438 642 806 474 559 429 680 749 734 644
#  626 649 805 718 840 630 654 762 568 613 522 737 648 443 640 540 460 593
#  801 611 802 745 483 690 492 709 705 560 752 701 537 487 596 702 486 724
#  548 464 790 534 748 494 590 468 509 818 816 536 753 774 621 569 658 798
#  641 542 692 639 765 570 638 599 632 779 527 564 833 504 842 508 417 598
#  741 607 761 848 546 439 755 760 526 713 700 666 566 495 688 612 477 427
#  839 819 720 459 503 624 529 563 482 796 445 746 786 554 672 787 499 844
#  450 815 838 803 736 633 600 679 517 792 743 488 421 841 708 507 505 456
#  435 561 518 565 728 784 552 609 764 697 723 551 444 719 496 541 830 812
#  677 420 595 617 809 500 826 434 513 478 797 363 399 463 780 452 575 837
#  794 824 428 823 781 849 489 431 457 768 831 359 820 573 576 558 817 449
#  440 415 821 530 350 446 425 740 481 783 358 845 451 458 469 423 404 836
#  473 835 466 491 351 827 843 365 532 414 453 471 401 810 832 470 447 422
#  825 430 436 426 408 847 418 437 410 454 407 455 462 386 405 383 395 467
#  433 442 424 448 441 367 412 382 373 419]
# Geography:  ['France' 'Spain' 'Germany']
# Gender:  ['Female' 'Male']
# Age:  [42 41 39 43 44 50 29 27 31 24 34 25 35 45 58 32 38 46 36 33 40 51 61 49
#  37 19 66 56 26 21 55 75 22 30 28 65 48 52 57 73 47 54 72 20 67 79 62 53
#  80 59 68 23 60 70 63 64 18 82 69 74 71 76 77 88 85 84 78 81 92 83]
# Tenure:  [ 2  1  8  7  4  6  3 10  5  9  0]
# Balance:  [     0.    83807.86 159660.8  ...  57369.61  75075.31 130142.79]
# NumOfProducts:  [1 3 2 4]
# HasCrCard:  [1 0]
# IsActiveMember:  [1 0]
# EstimatedSalary:  [101348.88 112542.58 113931.57 ...  42085.58  92888.52  38190.78]
# Exited:  [1 0]

# %% [markdown]
# #### Observations
# * No data that needs to be cleaned

# %% [markdown]
# ### Column Frequency

# %%
# get columns
cat_col = df.columns

# Occurrences of each unique value in each categorical column sorted by most frequent
for column in cat_col:
    print(df[column].value_counts(normalize=True, sort=True))
    print("-" * 50)
# Out:
# 850    0.0233
# 678    0.0063
# 655    0.0054
# 705    0.0053
# 667    0.0053
#         ...
# 404    0.0001
# 351    0.0001
# 365    0.0001
# 417    0.0001
# 419    0.0001
# Name: CreditScore, Length: 460, dtype: float64
# --------------------------------------------------
# France     0.5014
# Germany    0.2509
# Spain      0.2477
# Name: Geography, dtype: float64
# --------------------------------------------------
# Male      0.5457
# Female    0.4543
# Name: Gender, dtype: float64
# --------------------------------------------------
# 37    0.0478
# 38    0.0477
# 35    0.0474
# 36    0.0456
# 34    0.0447
#        ...
# 92    0.0002
# 82    0.0001
# 88    0.0001
# 85    0.0001
# 83    0.0001
# Name: Age, Length: 70, dtype: float64
# --------------------------------------------------
# 2     0.1048
# 1     0.1035
# 7     0.1028
# 8     0.1025
# 5     0.1012
# 3     0.1009
# 4     0.0989
# 9     0.0984
# 6     0.0967
# 10    0.0490
# 0     0.0413
# Name: Tenure, dtype: float64
# --------------------------------------------------
# 0.00         0.3617
# 130170.82    0.0002
# 105473.74    0.0002
# 85304.27     0.0001
# 159397.75    0.0001
#               ...
# 81556.89     0.0001
# 112687.69    0.0001
# 108698.96    0.0001
# 238387.56    0.0001
# 130142.79    0.0001
# Name: Balance, Length: 6382, dtype: float64
# --------------------------------------------------
# 1    0.5084
# 2    0.4590
# 3    0.0266
# 4    0.0060
# Name: NumOfProducts, dtype: float64
# --------------------------------------------------
# 1    0.7055
# 0    0.2945
# Name: HasCrCard, dtype: float64
# --------------------------------------------------
# 1    0.5151
# 0    0.4849
# Name: IsActiveMember, dtype: float64
# --------------------------------------------------
# 24924.92     0.0002
# 101348.88    0.0001
# 55313.44     0.0001
# 72500.68     0.0001
# 182692.80    0.0001
#               ...
# 120893.07    0.0001
# 188377.21    0.0001
# 55902.93     0.0001
# 4523.74      0.0001
# 38190.78     0.0001
# Name: EstimatedSalary, Length: 9999, dtype: float64
# --------------------------------------------------
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64
# --------------------------------------------------

# %% [markdown]
# #### Observations
# * 36.7% of customers have a zero balance.
# * 96.7% of customers have less than three products.
# * 70.5% of customers have a bank credit card.
# * 48.5% of customers are inactive. This is significant.

# %% [markdown]
# ### Dependent Variable Analysis

# %%
#checking the percentage of the dependent variable (y) in the dataset
(df.Exited.value_counts())/(df.Exited.count())
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %% [markdown]
# #### Observations
# * In the Exited column 0 mean the customer will stay and 1 means they will leave.
# * 79.6% of customers in this sample did not leave the bank.
# * 20.3% of customers left the bank.
#
# ||Actual Positive|Actual Negative|
# |-|-|-|
# |Predicted True|Predicted Leave and Left|**Predicted Leave and Stayed**|
# |Predicted False|**Predicted Stay and Left**|Predicted Stay and Stayed|
#
# Since we are focused on the customers who left **Precision** should be the main metric we try to optimize. Precision is True Positives divided by All Actual Positives.

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# #### CreditScore

# %%
histogram_boxplot(df, "CreditScore", kde=True)

# %% [markdown]
# ##### Observations
# * Distribution looks normal with two exceptions.
#   * Very slight left skew
#   * There is a spike at a credit score of 850 which should be looked into.
# * 50% of customers have a credit score over 650

# %% [markdown]
# #### Geography

# %%
labeled_barplot(df,"Geography", perc=True)

# %% [markdown]
# ##### Observations
# * 50% of customers are from France.
# * 50% of customers are from Germany and Spain.

# %% [markdown]
# #### Gender

# %%
labeled_barplot(df,"Gender", perc=True)

# %% [markdown]
# ##### Observations
# * There are 9.2% more male customers than there are women customers.

# %% [markdown]
# #### Age

# %%
histogram_boxplot(df, "Age", kde=True)

# %% [markdown]
# ##### Observations
# * Data is right-skewed.
# * The age group of 39 is almost double all other groups with the exception of 28 year-olds
# * 50% of customers are over 38 and 50% are between 18 and 38

# %% [markdown]
# #### Tenure

# %%
histogram_boxplot(df, "Tenure", kde=True)

# %% [markdown]
# ##### Observations
# * Roughly 1,000 customers are in each tenure group from 1 year to 9 years creating a flat distribution.
# * 0 years and 10 years have 400 and 500 customers respectively.

# %% [markdown]
# #### Balance

# %%
histogram_boxplot(df, "Balance", kde=True)

# %% [markdown]
# ##### Observations
# * Balance has a high negative skew because 3,500 customers have a balance of zero dollars.
# * 75% of customers have a balance below $125,000

# %% [markdown]
# #### NumOfProducts

# %%
labeled_barplot(df,"NumOfProducts", perc=True)

# %% [markdown]
# ##### Observations
# * The majority of customers only have one or two products.

# %% [markdown]
# #### HasCrCard

# %%
labeled_barplot(df,"HasCrCard", perc=True)

# %% [markdown]
# ##### Observations
# * Over 70% of customers have a credit card with the bank.

# %% [markdown]
# #### IsActiveMember

# %%
labeled_barplot(df,"IsActiveMember", perc=True)

# %% [markdown]
# ##### Observations
# * Only 51.5% of customers regularly use bank services.

# %% [markdown]
# #### EstimatedSalary

# %%
histogram_boxplot(df, "EstimatedSalary", kde=True)

# %% [markdown]
# ##### Observations
# * Flat distribution with no skew.

# %% [markdown]
# #### Exited

# %%
labeled_barplot(df,"Exited", perc=True)

# %% [markdown]
# ##### Observations
# * 20.4.% of customers in this sample have exited the bank.

# %% [markdown]
# ### Bivariate Analysis

# %% [markdown]
# #### Heat Map Correlation

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(df.corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %% [markdown]
# ##### Observations
# * There is a weak positive correlation between Age and Exited.
#   * As age goes up the exit rate tends to go up.
# * There is a weak negative correlation between NumOfProducts and Balance.
#   * As number of products increase the balance decreases.

# %% [markdown]
# #### CreditScore vs. Exited

# %%
distribution_plot_wrt_target(df,'CreditScore', 'Exited')

# %% [markdown]
# ##### Observations
# * Distributions are essentially the same with a very slight left skew.
# * Customers who have exited have more individuals with a credit score under 400.

# %% [markdown]
# #### Geography vs. Exited

# %%
stacked_barplot(df, "Geography", "Exited")
# Out:
# Exited        0     1    All
# Geography
# All        7963  2037  10000
# Germany    1695   814   2509
# France     4204   810   5014
# Spain      2064   413   2477
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Observations
# * The German market has the largest percentage of customers whom exit the bank.
#   * The German market has roughly a 65% retention rate compared with 80% for Spain and France.

# %% [markdown]
# #### Gender vs. Exited

# %%
stacked_barplot(df, "Gender", "Exited")
# Out:
# Exited     0     1    All
# Gender
# All     7963  2037  10000
# Female  3404  1139   4543
# Male    4559   898   5457
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Observations
# * Females tend to exit the bank as customers a little more than males.
#   * Females customers are less of a percentage than males so may be something which is turning female customers off to the bank.

# %% [markdown]
# #### Age vs. Exited

# %%
distribution_plot_wrt_target(df,'Age', 'Exited')

# %% [markdown]
# ##### Observations
# * Customers tend to exit the bank most between the ages of 40 and 50.
#   * This might show that the bank should reach out more to customers between this age.
# * Distribution of customers who have stayed with the bank is right or negative skewed.
# * Distribution of customers who have exited the bank is less skewed to the right.

# %% [markdown]
# #### Tenure vs. Exited

# %%
stacked_barplot(df, "Tenure", "Exited")
# Out:
# Exited     0     1    All
# Tenure
# All     7963  2037  10000
# 1        803   232   1035
# 3        796   213   1009
# 9        771   213    984
# 5        803   209   1012
# 4        786   203    989
# 2        847   201   1048
# 8        828   197   1025
# 6        771   196    967
# 7        851   177   1028
# 10       389   101    490
# 0        318    95    413
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Observations
# * This is a relatively uniform distribution where a little more than 20% of customers exit based on their tenure.

# %% [markdown]
# #### Balance vs. Exited

# %%
distribution_plot_wrt_target(df,'Balance', 'Exited')

# %% [markdown]
# ##### Observations
# * Bimodal distribution with one mode being an account balance of zero.
#   * Distribution between customers who have left and customers who have stayed is roughly the same.
# * 50% of customers who have exited have an account balance over $100,000.

# %% [markdown]
# #### NumOfProducts vs. Exited

# %%
stacked_barplot(df, "NumOfProducts", "Exited")
# Out:
# Exited            0     1    All
# NumOfProducts
# All            7963  2037  10000
# 1              3675  1409   5084
# 2              4242   348   4590
# 3                46   220    266
# 4                 0    60     60
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Observations
# * Every customer who has had over 3 products have left the bank.
#   * What is it about these products which is turing customers off to the bank? Is it because more products are complicating their experience with the bank?
# * Over 80% of customers who have had over 2 products have left the bank.
# * Customers with two products have the lowest attrition rate.

# %% [markdown]
# #### HasCrCard vs. Exited

# %%
stacked_barplot(df, "HasCrCard", "Exited")
# Out:
# Exited        0     1    All
# HasCrCard
# All        7963  2037  10000
# 1          5631  1424   7055
# 0          2332   613   2945
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Observations
# * Whether you have or don't have a bank credit card your attrition rate is about 20%.

# %% [markdown]
# #### IsActiveMember vs. Exited

# %%
stacked_barplot(df, "IsActiveMember", "Exited")
# Out:
# Exited             0     1    All
# IsActiveMember
# All             7963  2037  10000
# 0               3547  1302   4849
# 1               4416   735   5151
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ##### Observations
# * If a member is inactive, which means isn't currently using the bank's services. The exit rate is about 25%.
# * If a member is active that exit rate is about 15%.
# * Inactive members exit the bank more than active members.

# %% [markdown]
# #### EstimatedSalary vs. Exited

# %%
#stacked_barplot(df, "EstimatedSalary", "Exited")
distribution_plot_wrt_target(df,'EstimatedSalary', 'Exited')

# %% [markdown]
# ##### Observations
# * Distribution is uniform among different salaries for customers who exited and customers who did not exit.

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Train-validation-test Split

# %%
# Drop the dependent variable and create set X.
X = df.drop(['Exited'], axis=1);

# Take the independent variable anc create set y.
y = df['Exited'];

# Split the data into train and then a set we will split into test and validation.
X_train, X_large, y_train, y_large = train_test_split(X, y, test_size = .20, random_state = 42,stratify=y,shuffle = True);

# Split the larget set into test and validation
X_test, X_val, y_test, y_val = train_test_split(X_large, y_large, test_size = .50, random_state = 42,stratify=y_large, shuffle = True);

# Data should be split 80% training, 10% validation and 10% testing
print(X_train.shape, X_val.shape, X_test.shape);
print(y_train.shape, y_val.shape, y_test.shape);
# Out:
# (8000, 10) (1000, 10) (1000, 10)
# (8000,) (1000,) (1000,)

# %% [markdown]
# ### Dummy Variable Creation

# %%
X_train = pd.get_dummies(X_train, columns=["Geography","Gender"],drop_first=True);
X_test = pd.get_dummies(X_test, columns=["Geography","Gender"],drop_first=True);
X_val = pd.get_dummies(X_val, columns=["Geography","Gender"],drop_first=True);

print(X_train.shape, X_val.shape, X_test.shape);
print(y_train.shape, y_val.shape, y_test.shape);
# Out:
# (8000, 11) (1000, 11) (1000, 11)
# (8000,) (1000,) (1000,)

# %% [markdown]
# ### Data Normalization

# %%
cols_list = ["CreditScore","Age","Tenure","Balance","EstimatedSalary"]

# Use ScikitLearn standard scaler to distribute data on the same scale.
sc = StandardScaler()

X_train[cols_list] = sc.fit_transform(X_train[cols_list]);
X_val[cols_list] = sc.transform(X_val[cols_list]);
X_test[cols_list] = sc.transform(X_test[cols_list]);

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Model Evaluation Criterion

# %% [markdown]
# * Exited value of 0 means the customer stayed at the bank.
# * Exited value of 1 means the customer left the bank.
#
# <br>The confustion matrix looks like the following:
#
# ||Actual Positive|Actual Negative|
# |-|-|-|
# |Predicted True|Predicted Leave and Left|**Predicted Leave and Stayed**|
# |Predicted False|**Predicted Stay and Left**|Predicted Stay and Stayed|
#
# <br>**Type I** error is a customer which we predict to leave, but they stayed. Even though we were wrong this isn't as bad because the customer remained with the bank.
#
# **Type II error** is a customer which we predict to stay, but they leave. This will impact the business as we want to minimize churn.
#
# <br>**Conclusion**
#
# Since we are focused on the customers who left and we want to prevent customers who will leave in the future **Precision** should be the main metric we try to optimize.
#
# Precision is True Positives divided by All Actual Positives (True Positive + False Positive).

# %%
# Add a data frame which will track recall through our model evaluation.
train_metric_df = pd.DataFrame(columns=["recall"])
valid_metric_df = pd.DataFrame(columns=["recall"])

# %% [markdown]
# ### Model 0 - Neural Network with SGD Optimizer
#
# * Neural Network
#   * Sequential
#   * Input Layer: 64 Nodes with Relu Activation
#   * Hidden Layer 1: 32 Nodes with Relu Activation
#   * Output Layer 2: 1 Node with Sigmoid Activation
# * Optimizer
#   * Stochastic Gradient Descent
#   * Metric tracked: Recall
# * Loss Function
#   * BinaryCrossEntropy
# * Training
#   * Batch Size: 64
#   * Epochs: 100

# %%
# Clear the memory.
backend.clear_session()
# Make sure the seed is the same for all random functions
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_0 = Sequential()
# Adding the input layer with 64 neurons and relu as activation function
model_0.add(Dense(64, activation='relu', input_dim = X_train.shape[1]))
# Adding 32 neuron to the hidden layer with relu activation function.
model_0.add(Dense(32, activation='relu'))
# Since this is classification, we are using one output neuron and the Sigmoid activation function.
model_0.add(Dense(1, activation = 'sigmoid'))

# %%
#Schocastic Gradient Descent as the optimizer with a 0.001 learning rate.
optimizer = tf.keras.optimizers.SGD(0.001)

# We will be using recall to evaluate our model as we want to reduce the number of False Positives.
# That is customers we say are going to not leave the bank, but end up leaving.

metric = keras.metrics.Recall()
# metric = 'accuracy'
#metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# Use BinaryCrossEntropy as the loss function since this is a binary function.
losses = tf.keras.losses.BinaryCrossentropy()

# %%
# Compile the model
model_0.compile(loss=losses,optimizer=optimizer,metrics=metric)

# %%
model_0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2881 (11.25 KB)
# Trainable params: 2881 (11.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fit the neural network

history_0 = model_0.fit(
    X_train, y_train,
    batch_size=64,
    validation_data=(X_val,y_val),
    epochs=100,
    verbose=1
)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 4s 6ms/step - loss: 0.6265 - recall: 0.1049 - val_loss: 0.5992 - val_recall: 0.0394
# Epoch 2/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5846 - recall: 0.0086 - val_loss: 0.5657 - val_recall: 0.0099
# Epoch 3/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5569 - recall: 6.1350e-04 - val_loss: 0.5433 - val_recall: 0.0000e+00
# Epoch 4/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5382 - recall: 6.1350e-04 - val_loss: 0.5279 - val_recall: 0.0000e+00
# Epoch 5/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5252 - recall: 0.0000e+00 - val_loss: 0.5171 - val_recall: 0.0000e+00
# Epoch 6/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5161 - recall: 0.0000e+00 - val_loss: 0.5094 - val_recall: 0.0000e+00
# Epoch 7/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5093 - recall: 0.0000e+00 - val_loss: 0.5035 - val_recall: 0.0000e+00
# Epoch 8/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5041 - recall: 0.0000e+00 - val_loss: 0.4990 - val_recall: 0.0000e+00
# Epoch 9/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.5000 - recall: 0.0000e+00 - val_loss: 0.4953 - val_recall: 0.0000e+00
# Epoch 10/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4965 - recall: 0.0000e+00 - val_loss: 0.4921 - val_recall: 0.0000e+00
# Epoch 11/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4936 - recall: 0.0000e+00 - val_loss: 0.4894 - val_recall: 0.0000e+00
# Epoch 12/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4909 - recall: 0.0000e+00 - val_loss: 0.4869 - val_recall: 0.0000e+00
# Epoch 13/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4886 - recall: 0.0000e+00 - val_loss: 0.4847 - val_recall: 0.0000e+00
# Epoch 14/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4863 - recall: 0.0000e+00 - val_loss: 0.4826 - val_recall: 0.0000e+00
# Epoch 15/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4843 - recall: 0.0000e+00 - val_loss: 0.4806 - val_recall: 0.0000e+00
# Epoch 16/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4823 - recall: 0.0000e+00 - val_loss: 0.4787 - val_recall: 0.0000e+00
# Epoch 17/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4804 - recall: 0.0000e+00 - val_loss: 0.4769 - val_recall: 0.0000e+00
# Epoch 18/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4787 - recall: 0.0000e+00 - val_loss: 0.4752 - val_recall: 0.0000e+00
# Epoch 19/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4770 - recall: 0.0000e+00 - val_loss: 0.4735 - val_recall: 0.0000e+00
# Epoch 20/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4753 - recall: 0.0000e+00 - val_loss: 0.4719 - val_recall: 0.0000e+00
# Epoch 21/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.4737 - recall: 0.0000e+00 - val_loss: 0.4704 - val_recall: 0.0000e+00
# Epoch 22/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.4722 - recall: 0.0000e+00 - val_loss: 0.4689 - val_recall: 0.0000e+00
# Epoch 23/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.4707 - recall: 0.0000e+00 - val_loss: 0.4674 - val_recall: 0.0000e+00
# Epoch 24/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4693 - recall: 6.1350e-04 - val_loss: 0.4660 - val_recall: 0.0000e+00
# Epoch 25/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.4679 - recall: 6.1350e-04 - val_loss: 0.4647 - val_recall: 0.0000e+00
# Epoch 26/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4666 - recall: 6.1350e-04 - val_loss: 0.4634 - val_recall: 0.0000e+00
# Epoch 27/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4653 - recall: 0.0018 - val_loss: 0.4621 - val_recall: 0.0000e+00
# Epoch 28/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4640 - recall: 0.0025 - val_loss: 0.4609 - val_recall: 0.0000e+00
# Epoch 29/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4628 - recall: 0.0025 - val_loss: 0.4597 - val_recall: 0.0000e+00
# Epoch 30/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4617 - recall: 0.0025 - val_loss: 0.4585 - val_recall: 0.0000e+00
# Epoch 31/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4605 - recall: 0.0025 - val_loss: 0.4574 - val_recall: 0.0000e+00
# Epoch 32/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4594 - recall: 0.0037 - val_loss: 0.4563 - val_recall: 0.0000e+00
# Epoch 33/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4584 - recall: 0.0043 - val_loss: 0.4552 - val_recall: 0.0000e+00
# Epoch 34/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4573 - recall: 0.0049 - val_loss: 0.4542 - val_recall: 0.0000e+00
# Epoch 35/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4563 - recall: 0.0049 - val_loss: 0.4532 - val_recall: 0.0000e+00
# Epoch 36/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4553 - recall: 0.0061 - val_loss: 0.4523 - val_recall: 0.0000e+00
# Epoch 37/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4544 - recall: 0.0067 - val_loss: 0.4513 - val_recall: 0.0000e+00
# Epoch 38/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4535 - recall: 0.0092 - val_loss: 0.4504 - val_recall: 0.0049
# Epoch 39/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4526 - recall: 0.0098 - val_loss: 0.4495 - val_recall: 0.0049
# Epoch 40/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4517 - recall: 0.0123 - val_loss: 0.4487 - val_recall: 0.0049
# Epoch 41/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4509 - recall: 0.0153 - val_loss: 0.4478 - val_recall: 0.0049
# Epoch 42/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4501 - recall: 0.0172 - val_loss: 0.4470 - val_recall: 0.0049
# Epoch 43/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4493 - recall: 0.0215 - val_loss: 0.4462 - val_recall: 0.0099
# Epoch 44/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4485 - recall: 0.0245 - val_loss: 0.4454 - val_recall: 0.0148
# Epoch 45/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4477 - recall: 0.0264 - val_loss: 0.4447 - val_recall: 0.0148
# Epoch 46/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4470 - recall: 0.0288 - val_loss: 0.4439 - val_recall: 0.0148
# Epoch 47/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4463 - recall: 0.0301 - val_loss: 0.4432 - val_recall: 0.0148
# Epoch 48/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4456 - recall: 0.0331 - val_loss: 0.4425 - val_recall: 0.0148
# Epoch 49/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4450 - recall: 0.0356 - val_loss: 0.4418 - val_recall: 0.0148
# Epoch 50/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.4443 - recall: 0.0368 - val_loss: 0.4412 - val_recall: 0.0148
# Epoch 51/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.4437 - recall: 0.0399 - val_loss: 0.4405 - val_recall: 0.0148
# Epoch 52/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4431 - recall: 0.0423 - val_loss: 0.4399 - val_recall: 0.0197
# Epoch 53/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4425 - recall: 0.0454 - val_loss: 0.4393 - val_recall: 0.0197
# Epoch 54/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4419 - recall: 0.0503 - val_loss: 0.4387 - val_recall: 0.0197
# Epoch 55/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4413 - recall: 0.0515 - val_loss: 0.4381 - val_recall: 0.0296
# Epoch 56/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4408 - recall: 0.0521 - val_loss: 0.4375 - val_recall: 0.0296
# Epoch 57/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4402 - recall: 0.0564 - val_loss: 0.4370 - val_recall: 0.0345
# Epoch 58/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4397 - recall: 0.0607 - val_loss: 0.4365 - val_recall: 0.0345
# Epoch 59/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4392 - recall: 0.0632 - val_loss: 0.4360 - val_recall: 0.0394
# Epoch 60/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4387 - recall: 0.0656 - val_loss: 0.4355 - val_recall: 0.0394
# Epoch 61/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4382 - recall: 0.0681 - val_loss: 0.4350 - val_recall: 0.0394
# Epoch 62/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4378 - recall: 0.0724 - val_loss: 0.4345 - val_recall: 0.0394
# Epoch 63/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4373 - recall: 0.0767 - val_loss: 0.4340 - val_recall: 0.0443
# Epoch 64/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4369 - recall: 0.0798 - val_loss: 0.4336 - val_recall: 0.0443
# Epoch 65/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4364 - recall: 0.0840 - val_loss: 0.4332 - val_recall: 0.0443
# Epoch 66/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4360 - recall: 0.0865 - val_loss: 0.4327 - val_recall: 0.0493
# Epoch 67/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4356 - recall: 0.0877 - val_loss: 0.4323 - val_recall: 0.0591
# Epoch 68/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4352 - recall: 0.0890 - val_loss: 0.4319 - val_recall: 0.0640
# Epoch 69/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4348 - recall: 0.0920 - val_loss: 0.4315 - val_recall: 0.0640
# Epoch 70/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4344 - recall: 0.0951 - val_loss: 0.4311 - val_recall: 0.0640
# Epoch 71/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4341 - recall: 0.0969 - val_loss: 0.4308 - val_recall: 0.0690
# Epoch 72/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4337 - recall: 0.0975 - val_loss: 0.4304 - val_recall: 0.0690
# Epoch 73/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4333 - recall: 0.1000 - val_loss: 0.4301 - val_recall: 0.0690
# Epoch 74/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4330 - recall: 0.1025 - val_loss: 0.4297 - val_recall: 0.0690
# Epoch 75/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4327 - recall: 0.1031 - val_loss: 0.4294 - val_recall: 0.0690
# Epoch 76/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4323 - recall: 0.1086 - val_loss: 0.4291 - val_recall: 0.0690
# Epoch 77/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4320 - recall: 0.1098 - val_loss: 0.4287 - val_recall: 0.0690
# Epoch 78/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4317 - recall: 0.1098 - val_loss: 0.4284 - val_recall: 0.0788
# Epoch 79/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4314 - recall: 0.1117 - val_loss: 0.4281 - val_recall: 0.0837
# Epoch 80/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.4311 - recall: 0.1123 - val_loss: 0.4278 - val_recall: 0.0837
# Epoch 81/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4308 - recall: 0.1166 - val_loss: 0.4275 - val_recall: 0.0837
# Epoch 82/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4305 - recall: 0.1190 - val_loss: 0.4272 - val_recall: 0.0837
# Epoch 83/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4302 - recall: 0.1209 - val_loss: 0.4270 - val_recall: 0.0837
# Epoch 84/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4299 - recall: 0.1221 - val_loss: 0.4267 - val_recall: 0.0837
# Epoch 85/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4296 - recall: 0.1233 - val_loss: 0.4264 - val_recall: 0.0837
# Epoch 86/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4293 - recall: 0.1258 - val_loss: 0.4262 - val_recall: 0.0837
# Epoch 87/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4291 - recall: 0.1264 - val_loss: 0.4259 - val_recall: 0.0936
# Epoch 88/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4288 - recall: 0.1270 - val_loss: 0.4257 - val_recall: 0.0936
# Epoch 89/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4285 - recall: 0.1294 - val_loss: 0.4254 - val_recall: 0.0936
# Epoch 90/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4283 - recall: 0.1282 - val_loss: 0.4252 - val_recall: 0.0936
# Epoch 91/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4280 - recall: 0.1307 - val_loss: 0.4249 - val_recall: 0.0985
# Epoch 92/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.4278 - recall: 0.1344 - val_loss: 0.4247 - val_recall: 0.0985
# Epoch 93/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4275 - recall: 0.1344 - val_loss: 0.4245 - val_recall: 0.0985
# Epoch 94/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4273 - recall: 0.1399 - val_loss: 0.4242 - val_recall: 0.0985
# Epoch 95/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4270 - recall: 0.1399 - val_loss: 0.4240 - val_recall: 0.0985
# Epoch 96/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4268 - recall: 0.1442 - val_loss: 0.4238 - val_recall: 0.1034
# Epoch 97/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4265 - recall: 0.1448 - val_loss: 0.4236 - val_recall: 0.1034
# Epoch 98/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4263 - recall: 0.1466 - val_loss: 0.4234 - val_recall: 0.1034
# Epoch 99/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4261 - recall: 0.1497 - val_loss: 0.4232 - val_recall: 0.1034
# Epoch 100/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4259 - recall: 0.1528 - val_loss: 0.4230 - val_recall: 0.1034

# %% [markdown]
# #### Loss

# %%
#Train Loss vs Validation Loss
plt.plot(history_0.history['loss'])
plt.plot(history_0.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * The model is learning, however the loss is still very high.

# %% [markdown]
# #### Recall

# %%
#Train recall vs Validation recall
plt.plot(history_0.history['recall'])
plt.plot(history_0.history['val_recall'])
plt.title('model recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * Learning doesn't start until Epoch 20 and the data sets diverge immediately.
# * The Recall is very poor at 16% so we will try some ways to improve the accuracy of the model.

# %%
# Using .5 as the threshold on training
y_train_pred = model_0.predict(X_train)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 250/250 [==============================] - 1s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
# Using .5 as the threshold on validation
y_val_pred = model_0.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 32/32 [==============================] - 0s 2ms/step
# array([[ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False]])

# %%
model_name = "Model 0 - Neural Network with Schocastic Gradient Descent"

train_metric_df.loc[model_name] = recall_score(y_train, y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val, y_val_pred)

# %% [markdown]
# #### Classification Report

# %%
#Classification report
cr = classification_report(y_train, y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.98      0.89      6370
#            1       0.64      0.15      0.24      1630
#
#     accuracy                           0.81      8000
#    macro avg       0.73      0.56      0.57      8000
# weighted avg       0.78      0.81      0.76      8000

# %%
#classification report
cr=classification_report(y_val, y_val_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.98      0.89       797
#            1       0.60      0.10      0.18       203
#
#     accuracy                           0.80      1000
#    macro avg       0.71      0.54      0.53      1000
# weighted avg       0.77      0.80      0.74      1000

# %% [markdown]
# ##### Observations
# * Out of all the customers which which left the bank the model was only correct 15% of the time on training and 10% of the time on validation.
# * F1 score of 24% for training and 18% for validation shows that the model does a poor job in predicting when a customer will leave the bank.

# %% [markdown]
# #### Confusion matrix

# %%
# Confusion matrix returned an error. 'Series' object has no attribute 'predict'
# make_confusion_matrix(y_train, y_train_pred)
# make_confusion_matrix(y_val,y_val_pred)

# %% [markdown]
# ### Model 1 - Neural Network with Adam Optimizer
#
# * Neural Network
#   * Sequential
#   * Input Layer: 64 Nodes with Relu Activation
#   * Hidden Layer 1: 32 Nodes with Relu Activation
#   * Output Layer 2: 1 Node with Sigmoid Activation
# * Optimizer
#   * **Adam**
#   * Metric tracked: Recall
# * Loss Function
#   * BinaryCrossEntropy
# * Training
#   * Batch Size: 64
#   * Epochs: 100

# %%
# Clear the memory.
backend.clear_session()
# Make sure the seed is the same for all random functions
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_1 = Sequential()
# Adding the input layer with 64 neurons and relu as activation function
model_1.add(Dense(64, activation='relu', input_dim = X_train.shape[1]))
# Adding 32 neuron to the hidden layer with relu activation function.
model_1.add(Dense(32, activation='relu'))
# Since this is classification, we are using one output neuron and the Sigmoid activation function.
model_1.add(Dense(1, activation = 'sigmoid'))

# %%
# Adam as the optimizer with a 0.001 learning rate.
optimizer = tf.keras.optimizers.Adam(0.001)

# We will be using recall to evaluate our model as we want to reduce the number of False Positives.
# That is customers we say are going to not leave the bank, but end up leaving.
metric = keras.metrics.Recall()
# metric = 'accuracy'
#metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# Use BinaryCrossEntropy as the loss function since this is a binary function.
losses = tf.keras.losses.BinaryCrossentropy()

# %%
# Compile the model
model_1.compile(loss=losses,optimizer=optimizer,metrics=[metric])

# %%
model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2881 (11.25 KB)
# Trainable params: 2881 (11.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Fitting the ANN
history_1 = model_1.fit(
    X_train,y_train,
    batch_size=64, ## Complete the code to specify the batch size to use
    validation_data=(X_val,y_val),
    epochs=100, ## Complete the code to specify the number of epochs
    verbose=1
)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 2s 5ms/step - loss: 0.4633 - recall: 0.0767 - val_loss: 0.4219 - val_recall: 0.1823
# Epoch 2/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4169 - recall: 0.2399 - val_loss: 0.4108 - val_recall: 0.1724
# Epoch 3/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.4046 - recall: 0.2914 - val_loss: 0.4030 - val_recall: 0.3054
# Epoch 4/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3937 - recall: 0.3294 - val_loss: 0.3957 - val_recall: 0.3202
# Epoch 5/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3838 - recall: 0.3552 - val_loss: 0.3852 - val_recall: 0.3005
# Epoch 6/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3763 - recall: 0.3853 - val_loss: 0.3799 - val_recall: 0.3350
# Epoch 7/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3675 - recall: 0.3914 - val_loss: 0.3792 - val_recall: 0.4089
# Epoch 8/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3611 - recall: 0.4110 - val_loss: 0.3710 - val_recall: 0.3498
# Epoch 9/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3549 - recall: 0.4190 - val_loss: 0.3689 - val_recall: 0.3448
# Epoch 10/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3494 - recall: 0.4337 - val_loss: 0.3629 - val_recall: 0.3695
# Epoch 11/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3439 - recall: 0.4331 - val_loss: 0.3563 - val_recall: 0.4236
# Epoch 12/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3405 - recall: 0.4638 - val_loss: 0.3567 - val_recall: 0.3596
# Epoch 13/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3361 - recall: 0.4620 - val_loss: 0.3526 - val_recall: 0.3842
# Epoch 14/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3319 - recall: 0.4601 - val_loss: 0.3573 - val_recall: 0.4631
# Epoch 15/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3295 - recall: 0.4687 - val_loss: 0.3485 - val_recall: 0.4778
# Epoch 16/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3266 - recall: 0.4822 - val_loss: 0.3583 - val_recall: 0.4828
# Epoch 17/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3254 - recall: 0.4791 - val_loss: 0.3477 - val_recall: 0.4532
# Epoch 18/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3225 - recall: 0.4951 - val_loss: 0.3495 - val_recall: 0.4631
# Epoch 19/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3213 - recall: 0.4951 - val_loss: 0.3441 - val_recall: 0.4433
# Epoch 20/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3188 - recall: 0.4982 - val_loss: 0.3475 - val_recall: 0.4483
# Epoch 21/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3178 - recall: 0.5000 - val_loss: 0.3488 - val_recall: 0.4532
# Epoch 22/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3169 - recall: 0.5031 - val_loss: 0.3492 - val_recall: 0.5074
# Epoch 23/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3150 - recall: 0.5074 - val_loss: 0.3505 - val_recall: 0.4828
# Epoch 24/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3148 - recall: 0.5160 - val_loss: 0.3499 - val_recall: 0.4532
# Epoch 25/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3135 - recall: 0.5098 - val_loss: 0.3465 - val_recall: 0.4483
# Epoch 26/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3126 - recall: 0.5117 - val_loss: 0.3468 - val_recall: 0.4286
# Epoch 27/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3105 - recall: 0.5196 - val_loss: 0.3475 - val_recall: 0.4138
# Epoch 28/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3102 - recall: 0.5086 - val_loss: 0.3460 - val_recall: 0.4877
# Epoch 29/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3096 - recall: 0.5153 - val_loss: 0.3499 - val_recall: 0.4236
# Epoch 30/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3095 - recall: 0.5276 - val_loss: 0.3464 - val_recall: 0.4433
# Epoch 31/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3084 - recall: 0.5227 - val_loss: 0.3459 - val_recall: 0.4581
# Epoch 32/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3074 - recall: 0.5233 - val_loss: 0.3516 - val_recall: 0.5419
# Epoch 33/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3050 - recall: 0.5190 - val_loss: 0.3455 - val_recall: 0.4926
# Epoch 34/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3067 - recall: 0.5319 - val_loss: 0.3513 - val_recall: 0.4433
# Epoch 35/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3051 - recall: 0.5276 - val_loss: 0.3468 - val_recall: 0.4877
# Epoch 36/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3041 - recall: 0.5178 - val_loss: 0.3518 - val_recall: 0.4581
# Epoch 37/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3019 - recall: 0.5294 - val_loss: 0.3499 - val_recall: 0.4729
# Epoch 38/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3029 - recall: 0.5362 - val_loss: 0.3486 - val_recall: 0.4680
# Epoch 39/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3006 - recall: 0.5294 - val_loss: 0.3495 - val_recall: 0.4975
# Epoch 40/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2991 - recall: 0.5362 - val_loss: 0.3505 - val_recall: 0.4433
# Epoch 41/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3004 - recall: 0.5190 - val_loss: 0.3488 - val_recall: 0.4877
# Epoch 42/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3004 - recall: 0.5331 - val_loss: 0.3491 - val_recall: 0.4828
# Epoch 43/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2973 - recall: 0.5399 - val_loss: 0.3542 - val_recall: 0.4975
# Epoch 44/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2979 - recall: 0.5387 - val_loss: 0.3500 - val_recall: 0.4877
# Epoch 45/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2966 - recall: 0.5356 - val_loss: 0.3514 - val_recall: 0.4581
# Epoch 46/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2954 - recall: 0.5436 - val_loss: 0.3493 - val_recall: 0.4828
# Epoch 47/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2958 - recall: 0.5448 - val_loss: 0.3515 - val_recall: 0.5025
# Epoch 48/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2948 - recall: 0.5472 - val_loss: 0.3567 - val_recall: 0.4680
# Epoch 49/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2940 - recall: 0.5583 - val_loss: 0.3551 - val_recall: 0.4286
# Epoch 50/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2923 - recall: 0.5491 - val_loss: 0.3570 - val_recall: 0.4631
# Epoch 51/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2923 - recall: 0.5503 - val_loss: 0.3551 - val_recall: 0.5271
# Epoch 52/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2920 - recall: 0.5479 - val_loss: 0.3605 - val_recall: 0.4631
# Epoch 53/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2912 - recall: 0.5497 - val_loss: 0.3549 - val_recall: 0.4877
# Epoch 54/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2895 - recall: 0.5448 - val_loss: 0.3586 - val_recall: 0.4532
# Epoch 55/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2919 - recall: 0.5429 - val_loss: 0.3579 - val_recall: 0.4926
# Epoch 56/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2901 - recall: 0.5613 - val_loss: 0.3564 - val_recall: 0.4631
# Epoch 57/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2885 - recall: 0.5552 - val_loss: 0.3589 - val_recall: 0.5271
# Epoch 58/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2885 - recall: 0.5552 - val_loss: 0.3586 - val_recall: 0.4926
# Epoch 59/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2879 - recall: 0.5564 - val_loss: 0.3559 - val_recall: 0.4680
# Epoch 60/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2862 - recall: 0.5644 - val_loss: 0.3607 - val_recall: 0.4828
# Epoch 61/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2877 - recall: 0.5571 - val_loss: 0.3597 - val_recall: 0.4975
# Epoch 62/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2851 - recall: 0.5577 - val_loss: 0.3521 - val_recall: 0.5025
# Epoch 63/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2838 - recall: 0.5607 - val_loss: 0.3644 - val_recall: 0.4335
# Epoch 64/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2854 - recall: 0.5669 - val_loss: 0.3615 - val_recall: 0.4828
# Epoch 65/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2844 - recall: 0.5656 - val_loss: 0.3554 - val_recall: 0.5025
# Epoch 66/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2870 - recall: 0.5669 - val_loss: 0.3619 - val_recall: 0.5271
# Epoch 67/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2841 - recall: 0.5742 - val_loss: 0.3564 - val_recall: 0.5320
# Epoch 68/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2821 - recall: 0.5656 - val_loss: 0.3585 - val_recall: 0.5123
# Epoch 69/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.2825 - recall: 0.5724 - val_loss: 0.3609 - val_recall: 0.5222
# Epoch 70/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2817 - recall: 0.5663 - val_loss: 0.3652 - val_recall: 0.4975
# Epoch 71/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2824 - recall: 0.5681 - val_loss: 0.3667 - val_recall: 0.5517
# Epoch 72/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2797 - recall: 0.5890 - val_loss: 0.3666 - val_recall: 0.5123
# Epoch 73/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2822 - recall: 0.5724 - val_loss: 0.3633 - val_recall: 0.5074
# Epoch 74/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2793 - recall: 0.5755 - val_loss: 0.3647 - val_recall: 0.4828
# Epoch 75/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2787 - recall: 0.5761 - val_loss: 0.3644 - val_recall: 0.4729
# Epoch 76/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2772 - recall: 0.5883 - val_loss: 0.3624 - val_recall: 0.4532
# Epoch 77/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2771 - recall: 0.5779 - val_loss: 0.3685 - val_recall: 0.5567
# Epoch 78/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2770 - recall: 0.5926 - val_loss: 0.3662 - val_recall: 0.5222
# Epoch 79/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2776 - recall: 0.5816 - val_loss: 0.3628 - val_recall: 0.4778
# Epoch 80/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2753 - recall: 0.5834 - val_loss: 0.3755 - val_recall: 0.5172
# Epoch 81/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2766 - recall: 0.5877 - val_loss: 0.3707 - val_recall: 0.4680
# Epoch 82/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2755 - recall: 0.5939 - val_loss: 0.3744 - val_recall: 0.5222
# Epoch 83/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2756 - recall: 0.5828 - val_loss: 0.3687 - val_recall: 0.5468
# Epoch 84/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2751 - recall: 0.5975 - val_loss: 0.3690 - val_recall: 0.4975
# Epoch 85/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2747 - recall: 0.5865 - val_loss: 0.3699 - val_recall: 0.4877
# Epoch 86/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2737 - recall: 0.5877 - val_loss: 0.3785 - val_recall: 0.5468
# Epoch 87/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2727 - recall: 0.6025 - val_loss: 0.3730 - val_recall: 0.4778
# Epoch 88/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2723 - recall: 0.5896 - val_loss: 0.3755 - val_recall: 0.5271
# Epoch 89/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2722 - recall: 0.5896 - val_loss: 0.3753 - val_recall: 0.4680
# Epoch 90/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2728 - recall: 0.5994 - val_loss: 0.3664 - val_recall: 0.4729
# Epoch 91/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2708 - recall: 0.5951 - val_loss: 0.3720 - val_recall: 0.4680
# Epoch 92/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2702 - recall: 0.5896 - val_loss: 0.3729 - val_recall: 0.5419
# Epoch 93/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2720 - recall: 0.5902 - val_loss: 0.3669 - val_recall: 0.4926
# Epoch 94/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2697 - recall: 0.6000 - val_loss: 0.3714 - val_recall: 0.4778
# Epoch 95/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.2699 - recall: 0.5969 - val_loss: 0.3725 - val_recall: 0.4877
# Epoch 96/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2693 - recall: 0.6000 - val_loss: 0.3783 - val_recall: 0.5222
# Epoch 97/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.2690 - recall: 0.6018 - val_loss: 0.3821 - val_recall: 0.4877
# Epoch 98/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.2694 - recall: 0.6031 - val_loss: 0.3854 - val_recall: 0.5369
# Epoch 99/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.2689 - recall: 0.5933 - val_loss: 0.3769 - val_recall: 0.4877
# Epoch 100/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.2705 - recall: 0.6080 - val_loss: 0.3770 - val_recall: 0.5271

# %% [markdown]
# #### Loss

# %%
#Train Loss vs Validation Loss
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * The model fails on the validation set to generalize.
# * Loss is still high, but better.

# %% [markdown]
# #### Recall

# %%
#Train recall vs Validation recall
plt.plot(history_1.history['recall'])
plt.plot(history_1.history['val_recall'])
plt.title('model recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * Recall is a lot better at around 60%, but the validation set fluctuates between 40% and 50% recall.

# %%
#Using 0.5 as the threshold on training
y_train_pred=model_1.predict(X_train)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 250/250 [==============================] - 0s 1ms/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Using .5 as the threshold on validation
y_val_pred=model_1.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 32/32 [==============================] - 0s 1ms/step
# array([[False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False]])

# %%
model_name = "Model 1 - Neural Network with Adam Optimizer"

train_metric_df.loc[model_name] = recall_score(y_train,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# #### Classification Report

# %%
#Classification report
cr=classification_report(y_train,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.97      0.94      6370
#            1       0.83      0.59      0.69      1630
#
#     accuracy                           0.89      8000
#    macro avg       0.87      0.78      0.81      8000
# weighted avg       0.89      0.89      0.89      8000

# %%
#Classification report
cr=classification_report(y_val, y_val_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92       797
#            1       0.74      0.53      0.61       203
#
#     accuracy                           0.87      1000
#    macro avg       0.81      0.74      0.77      1000
# weighted avg       0.86      0.87      0.86      1000

# %% [markdown]
# ##### Observations
# * The model improved to 60% recall on training data and 53% on validataion.
# * F1 score also imporved from on training to 69% and 61% on validation.
# * Better results than Model 0

# %% [markdown]
# #### Confusion Matrix

# %%
# Confusion matrix returned an error. 'Series' object has no attribute 'predict'
# make_confusion_matrix(y_train, y_train_pred)
# make_confusion_matrix(y_val,y_val_pred)

# %% [markdown]
# ### Model 2 - Neural Network with Adam Optimizer and Dropout
# * Neural Network
#   * Sequential
#   * Input Layer: 64 Nodes with Relu Activation
#   * **Dropout** with ratio of 0.20
#   * Hidden Layer 1: 32 Nodes with Relu Activation
#   * Hidden Layer 2: 16 Nodes with Relu Activation
#   * **Dropout** with ratio of 0.10
#   * Hidden Layer 3: 8 Nodes with Relu Activation
#   * Output Layer: 1 Node with Sigmoid Activation
# * Optimizer
#   * **Adam Optimizer**
#   * Metric tracked: Recall
# * Loss Function
#   * BinaryCrossEntropy
# * Training
#   * Batch Size: 64
#   * Epochs: 100

# %%
# Clear the memory.
backend.clear_session()
# Make sure the seed is the same for all random functions
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_2 = Sequential()
# Adding the input layer with 64 neurons and relu as activation function
model_2.add(Dense(64, activation='relu', input_dim = X_train.shape[1]))
model_2.add(Dropout(0.2))
# Adding 32 neuron to the hidden layer with relu activation function.
model_2.add(Dense(32, activation='relu'))
model_2.add(Dense(16, activation='relu'))
model_2.add(Dropout(0.1))
model_2.add(Dense(8, activation='relu'))
# Since this is classification, we are using one output neuron and the Sigmoid activation function.
model_2.add(Dense(1, activation = 'sigmoid'))

# %%
# Adam as the optimizer with a 0.001 learning rate.
optimizer = tf.keras.optimizers.Adam(0.001)

# We will be using recall to evaluate our model as we want to reduce the number of False Positives.
# That is customers we say are going to not leave the bank, but end up leaving.
metric = keras.metrics.Recall()
# metric = 'accuracy'
#metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# Use BinaryCrossEntropy as the loss function since this is a binary function.
losses = tf.keras.losses.BinaryCrossentropy()

# %%
# Compile the model
model_2.compile(loss=losses,optimizer=optimizer,metrics=[metric])

# %%
model_2.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_3 (Dense)             (None, 8)                 136
#
#  dense_4 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 3521 (13.75 KB)
# Trainable params: 3521 (13.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Fitting the ANN
history_2 = model_2.fit(
    X_train,y_train,
    batch_size=64, ## Complete the code to specify the batch size to use
    validation_data=(X_val,y_val),
    epochs=100, ## Complete the code to specify the number of epochs
    verbose=1
)
# Out:
# Epoch 1/100
# 125/125 [==============================] - 3s 5ms/step - loss: 0.5122 - recall: 0.0405 - val_loss: 0.4338 - val_recall: 0.0000e+00
# Epoch 2/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.4370 - recall: 0.1129 - val_loss: 0.4236 - val_recall: 0.1281
# Epoch 3/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.4311 - recall: 0.1840 - val_loss: 0.4215 - val_recall: 0.1527
# Epoch 4/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.4223 - recall: 0.2202 - val_loss: 0.4145 - val_recall: 0.2069
# Epoch 5/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.4155 - recall: 0.2485 - val_loss: 0.4088 - val_recall: 0.1921
# Epoch 6/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.4114 - recall: 0.2761 - val_loss: 0.4036 - val_recall: 0.2118
# Epoch 7/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.4051 - recall: 0.2896 - val_loss: 0.4034 - val_recall: 0.2808
# Epoch 8/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3989 - recall: 0.3294 - val_loss: 0.3952 - val_recall: 0.3005
# Epoch 9/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3934 - recall: 0.3405 - val_loss: 0.3895 - val_recall: 0.2857
# Epoch 10/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3870 - recall: 0.3546 - val_loss: 0.3810 - val_recall: 0.3350
# Epoch 11/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3809 - recall: 0.3589 - val_loss: 0.3726 - val_recall: 0.3892
# Epoch 12/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3742 - recall: 0.4055 - val_loss: 0.3668 - val_recall: 0.3202
# Epoch 13/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3656 - recall: 0.4184 - val_loss: 0.3607 - val_recall: 0.3498
# Epoch 14/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3588 - recall: 0.4129 - val_loss: 0.3592 - val_recall: 0.3990
# Epoch 15/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3580 - recall: 0.4313 - val_loss: 0.3536 - val_recall: 0.4039
# Epoch 16/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3533 - recall: 0.4325 - val_loss: 0.3521 - val_recall: 0.4433
# Epoch 17/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3506 - recall: 0.4460 - val_loss: 0.3481 - val_recall: 0.4236
# Epoch 18/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3468 - recall: 0.4564 - val_loss: 0.3456 - val_recall: 0.4433
# Epoch 19/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3419 - recall: 0.4669 - val_loss: 0.3474 - val_recall: 0.4286
# Epoch 20/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3422 - recall: 0.4656 - val_loss: 0.3477 - val_recall: 0.4286
# Epoch 21/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3362 - recall: 0.4693 - val_loss: 0.3481 - val_recall: 0.4581
# Epoch 22/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3367 - recall: 0.4626 - val_loss: 0.3470 - val_recall: 0.4680
# Epoch 23/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3394 - recall: 0.4595 - val_loss: 0.3492 - val_recall: 0.4532
# Epoch 24/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3402 - recall: 0.4699 - val_loss: 0.3472 - val_recall: 0.3941
# Epoch 25/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3363 - recall: 0.4742 - val_loss: 0.3440 - val_recall: 0.4384
# Epoch 26/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3328 - recall: 0.4699 - val_loss: 0.3471 - val_recall: 0.3941
# Epoch 27/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3335 - recall: 0.4669 - val_loss: 0.3447 - val_recall: 0.4187
# Epoch 28/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3324 - recall: 0.4736 - val_loss: 0.3419 - val_recall: 0.4335
# Epoch 29/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3319 - recall: 0.4736 - val_loss: 0.3453 - val_recall: 0.4187
# Epoch 30/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3298 - recall: 0.4748 - val_loss: 0.3448 - val_recall: 0.4384
# Epoch 31/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3280 - recall: 0.4712 - val_loss: 0.3448 - val_recall: 0.4483
# Epoch 32/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3317 - recall: 0.4626 - val_loss: 0.3469 - val_recall: 0.4384
# Epoch 33/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3298 - recall: 0.4804 - val_loss: 0.3465 - val_recall: 0.4581
# Epoch 34/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3290 - recall: 0.4896 - val_loss: 0.3473 - val_recall: 0.4384
# Epoch 35/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3320 - recall: 0.4718 - val_loss: 0.3444 - val_recall: 0.4286
# Epoch 36/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3276 - recall: 0.4730 - val_loss: 0.3445 - val_recall: 0.4384
# Epoch 37/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3244 - recall: 0.4718 - val_loss: 0.3531 - val_recall: 0.4138
# Epoch 38/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3260 - recall: 0.4902 - val_loss: 0.3474 - val_recall: 0.4631
# Epoch 39/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3262 - recall: 0.4810 - val_loss: 0.3459 - val_recall: 0.4335
# Epoch 40/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3253 - recall: 0.4871 - val_loss: 0.3467 - val_recall: 0.3941
# Epoch 41/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3248 - recall: 0.4724 - val_loss: 0.3462 - val_recall: 0.4335
# Epoch 42/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3196 - recall: 0.4859 - val_loss: 0.3470 - val_recall: 0.4236
# Epoch 43/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3232 - recall: 0.4877 - val_loss: 0.3482 - val_recall: 0.4335
# Epoch 44/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3218 - recall: 0.4908 - val_loss: 0.3465 - val_recall: 0.4187
# Epoch 45/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3218 - recall: 0.4914 - val_loss: 0.3469 - val_recall: 0.4138
# Epoch 46/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3230 - recall: 0.4681 - val_loss: 0.3441 - val_recall: 0.4335
# Epoch 47/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3201 - recall: 0.4785 - val_loss: 0.3477 - val_recall: 0.4680
# Epoch 48/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3224 - recall: 0.4865 - val_loss: 0.3474 - val_recall: 0.4236
# Epoch 49/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3229 - recall: 0.4755 - val_loss: 0.3464 - val_recall: 0.4187
# Epoch 50/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3205 - recall: 0.4859 - val_loss: 0.3480 - val_recall: 0.4433
# Epoch 51/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3174 - recall: 0.4945 - val_loss: 0.3452 - val_recall: 0.4877
# Epoch 52/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3171 - recall: 0.5012 - val_loss: 0.3446 - val_recall: 0.4286
# Epoch 53/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3174 - recall: 0.4914 - val_loss: 0.3454 - val_recall: 0.4532
# Epoch 54/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3183 - recall: 0.4853 - val_loss: 0.3489 - val_recall: 0.4187
# Epoch 55/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3132 - recall: 0.4945 - val_loss: 0.3449 - val_recall: 0.4483
# Epoch 56/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3138 - recall: 0.4945 - val_loss: 0.3461 - val_recall: 0.4483
# Epoch 57/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3127 - recall: 0.5037 - val_loss: 0.3474 - val_recall: 0.4680
# Epoch 58/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3141 - recall: 0.4951 - val_loss: 0.3439 - val_recall: 0.4581
# Epoch 59/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3188 - recall: 0.4902 - val_loss: 0.3410 - val_recall: 0.4581
# Epoch 60/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3135 - recall: 0.5025 - val_loss: 0.3446 - val_recall: 0.4433
# Epoch 61/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3154 - recall: 0.5025 - val_loss: 0.3468 - val_recall: 0.4433
# Epoch 62/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3097 - recall: 0.4988 - val_loss: 0.3462 - val_recall: 0.4483
# Epoch 63/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3109 - recall: 0.5031 - val_loss: 0.3516 - val_recall: 0.4335
# Epoch 64/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3148 - recall: 0.4877 - val_loss: 0.3466 - val_recall: 0.4384
# Epoch 65/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3129 - recall: 0.4890 - val_loss: 0.3440 - val_recall: 0.4433
# Epoch 66/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3109 - recall: 0.4975 - val_loss: 0.3531 - val_recall: 0.4483
# Epoch 67/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3138 - recall: 0.4975 - val_loss: 0.3482 - val_recall: 0.4631
# Epoch 68/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3083 - recall: 0.4877 - val_loss: 0.3533 - val_recall: 0.4483
# Epoch 69/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3092 - recall: 0.4994 - val_loss: 0.3486 - val_recall: 0.4631
# Epoch 70/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3062 - recall: 0.5135 - val_loss: 0.3527 - val_recall: 0.4828
# Epoch 71/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3092 - recall: 0.5031 - val_loss: 0.3532 - val_recall: 0.4975
# Epoch 72/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3068 - recall: 0.5147 - val_loss: 0.3530 - val_recall: 0.4631
# Epoch 73/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3067 - recall: 0.5184 - val_loss: 0.3483 - val_recall: 0.4581
# Epoch 74/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3087 - recall: 0.5012 - val_loss: 0.3538 - val_recall: 0.4483
# Epoch 75/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3056 - recall: 0.5184 - val_loss: 0.3531 - val_recall: 0.4335
# Epoch 76/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3077 - recall: 0.5141 - val_loss: 0.3495 - val_recall: 0.3990
# Epoch 77/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3030 - recall: 0.5049 - val_loss: 0.3534 - val_recall: 0.4581
# Epoch 78/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3044 - recall: 0.5209 - val_loss: 0.3508 - val_recall: 0.4729
# Epoch 79/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3047 - recall: 0.5043 - val_loss: 0.3526 - val_recall: 0.4926
# Epoch 80/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3078 - recall: 0.5092 - val_loss: 0.3527 - val_recall: 0.4631
# Epoch 81/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3043 - recall: 0.5092 - val_loss: 0.3503 - val_recall: 0.4581
# Epoch 82/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3076 - recall: 0.5117 - val_loss: 0.3504 - val_recall: 0.4483
# Epoch 83/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3030 - recall: 0.5067 - val_loss: 0.3606 - val_recall: 0.4680
# Epoch 84/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3072 - recall: 0.5172 - val_loss: 0.3476 - val_recall: 0.4680
# Epoch 85/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3038 - recall: 0.5166 - val_loss: 0.3515 - val_recall: 0.4581
# Epoch 86/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3012 - recall: 0.5288 - val_loss: 0.3554 - val_recall: 0.4877
# Epoch 87/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3033 - recall: 0.5135 - val_loss: 0.3540 - val_recall: 0.4581
# Epoch 88/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3041 - recall: 0.5110 - val_loss: 0.3590 - val_recall: 0.4532
# Epoch 89/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3055 - recall: 0.5141 - val_loss: 0.3574 - val_recall: 0.4581
# Epoch 90/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3020 - recall: 0.5080 - val_loss: 0.3543 - val_recall: 0.4384
# Epoch 91/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2978 - recall: 0.5258 - val_loss: 0.3530 - val_recall: 0.4483
# Epoch 92/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3028 - recall: 0.5067 - val_loss: 0.3569 - val_recall: 0.4729
# Epoch 93/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3000 - recall: 0.5233 - val_loss: 0.3614 - val_recall: 0.4729
# Epoch 94/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3007 - recall: 0.5117 - val_loss: 0.3548 - val_recall: 0.4483
# Epoch 95/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3025 - recall: 0.5110 - val_loss: 0.3526 - val_recall: 0.4335
# Epoch 96/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2980 - recall: 0.5129 - val_loss: 0.3608 - val_recall: 0.4384
# Epoch 97/100
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3009 - recall: 0.5227 - val_loss: 0.3573 - val_recall: 0.4384
# Epoch 98/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2997 - recall: 0.5270 - val_loss: 0.3557 - val_recall: 0.4483
# Epoch 99/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2961 - recall: 0.5166 - val_loss: 0.3652 - val_recall: 0.3695
# Epoch 100/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2975 - recall: 0.5117 - val_loss: 0.3596 - val_recall: 0.4581

# %% [markdown]
# #### Loss

# %%
#Train Loss vs Validation Loss
plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * The model fails on the validation set to generalize.
# * Loss is more flat in this model as in the last model which had a sharper slope towards 1.

# %% [markdown]
# #### Recall

# %%
#Train recall vs Validation recall
plt.plot(history_2.history['recall'])
plt.plot(history_2.history['val_recall'])
plt.title('model recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * Recall is not as good as Model 1. The distance between train and validation might be a little smaller.

# %%
#Using 0.5 as the threshold on training
y_train_pred=model_2.predict(X_train)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 250/250 [==============================] - 0s 2ms/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [ True]])

# %%
#Using .5 as the threshold on validation
y_val_pred=model_2.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 32/32 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False]])

# %%
model_name = "Model 2 - Neural Network with Adam Optimizer and Dropout"

train_metric_df.loc[model_name] = recall_score(y_train,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# #### Classification Report

# %%
#Classification report
cr=classification_report(y_train,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.98      0.94      6370
#            1       0.88      0.54      0.67      1630
#
#     accuracy                           0.89      8000
#    macro avg       0.89      0.76      0.80      8000
# weighted avg       0.89      0.89      0.88      8000

# %%
#Classification report
cr=classification_report(y_val, y_val_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91       797
#            1       0.73      0.46      0.56       203
#
#     accuracy                           0.86      1000
#    macro avg       0.80      0.71      0.74      1000
# weighted avg       0.85      0.86      0.84      1000

# %% [markdown]
# ##### Observations
# * The model regressed to 53% recall on training data and 44% on validataion.
# * F1 score also regressed from on training to 66% and 55% on validation.
# * Not as good of results as model 1

# %% [markdown]
# #### Confusion Matrix

# %%
# Confusion matrix returned an error. 'Series' object has no attribute 'predict'
# make_confusion_matrix(y_train, y_train_pred)
# make_confusion_matrix(y_val,y_val_pred)

# %% [markdown]
# ### Model 3 - Neural Network with Balanced Data (by applying SMOTE) and SGD Optimizer
# * **SMOTE** applied to training set.
# * Neural Network
#   * Sequential
#   * Input Layer: 64 Nodes with Relu Activation
#   * Hidden Layer 1: 32 Nodes with Relu Activation
#   * Hidden Layer 2: 16 Nodes with Relu Activation
#   * Output Layer: 1 Node with Sigmoid Activation
# * Optimizer
#   * **Schocastic Gradient Descent Optimizer**
#   * Metric tracked: Recall
# * Loss Function
#   * BinaryCrossEntropy
# * Training
#   * Batch Size: 64
#   * Epochs: 100

# %% [markdown]
# #### Add SMOTE to training set

# %%
sm  = SMOTE(random_state=42)
#Complete the code to fit SMOTE on the training data.
X_train_smote, y_train_smote= sm.fit_resample(X_train,y_train)
print('After UpSampling, the shape of train_X: {}'.format(X_train_smote.shape))
print('After UpSampling, the shape of train_y: {} \n'.format(y_train_smote.shape))
# Out:
# After UpSampling, the shape of train_X: (12740, 11)
# After UpSampling, the shape of train_y: (12740,)

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_3 = Sequential()
# Adding the input layer with 64 neurons and relu as activation function
model_3.add(Dense(64, activation='relu', input_dim = X_train.shape[1]))
# Adding 32 neuron to the hidden layer with relu activation function.
model_3.add(Dense(32, activation='relu'))
# Adding 16 neuron to the hidden layer with relu activation function.
model_3.add(Dense(16, activation='relu'))
# Since this is classification, we are using one output neuron and the Sigmoid activation function.
model_3.add(Dense(1, activation = 'sigmoid'))

# %%
#Schocastic Gradient Descent as the optimizer with a 0.001 learning rate.
optimizer = tf.keras.optimizers.SGD(0.001)

# We will be using recall to evaluate our model as we want to reduce the number of False Positives.
# That is customers we say are going to not leave the bank, but end up leaving.

metric = keras.metrics.Recall()
# metric = 'accuracy'
#metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# Use BinaryCrossEntropy as the loss function since this is a binary function.
losses = tf.keras.losses.BinaryCrossentropy()

# %%
# Compile the model
model_3.compile(loss=losses,optimizer=optimizer,metrics=[metric])

# %%
model_3.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 3393 (13.25 KB)
# Trainable params: 3393 (13.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fit the neural network
history_3 = model_3.fit(
    X_train_smote, y_train_smote,
    batch_size=64,
    epochs=100,
    verbose=1,
    validation_data = (X_val,y_val)
)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 3s 5ms/step - loss: 0.6910 - recall: 0.5546 - val_loss: 0.6918 - val_recall: 0.5271
# Epoch 2/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6885 - recall: 0.5796 - val_loss: 0.6895 - val_recall: 0.5419
# Epoch 3/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6860 - recall: 0.5961 - val_loss: 0.6873 - val_recall: 0.5567
# Epoch 4/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6835 - recall: 0.6155 - val_loss: 0.6849 - val_recall: 0.5714
# Epoch 5/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6810 - recall: 0.6297 - val_loss: 0.6822 - val_recall: 0.5616
# Epoch 6/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6785 - recall: 0.6438 - val_loss: 0.6800 - val_recall: 0.5764
# Epoch 7/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6760 - recall: 0.6512 - val_loss: 0.6775 - val_recall: 0.6010
# Epoch 8/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6735 - recall: 0.6551 - val_loss: 0.6748 - val_recall: 0.6207
# Epoch 9/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6708 - recall: 0.6584 - val_loss: 0.6725 - val_recall: 0.6502
# Epoch 10/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6681 - recall: 0.6579 - val_loss: 0.6697 - val_recall: 0.6502
# Epoch 11/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6652 - recall: 0.6694 - val_loss: 0.6665 - val_recall: 0.6502
# Epoch 12/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6622 - recall: 0.6683 - val_loss: 0.6629 - val_recall: 0.6502
# Epoch 13/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6590 - recall: 0.6695 - val_loss: 0.6597 - val_recall: 0.6502
# Epoch 14/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6557 - recall: 0.6750 - val_loss: 0.6565 - val_recall: 0.6650
# Epoch 15/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.6523 - recall: 0.6750 - val_loss: 0.6527 - val_recall: 0.6650
# Epoch 16/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6488 - recall: 0.6757 - val_loss: 0.6486 - val_recall: 0.6650
# Epoch 17/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6451 - recall: 0.6743 - val_loss: 0.6443 - val_recall: 0.6601
# Epoch 18/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6413 - recall: 0.6752 - val_loss: 0.6391 - val_recall: 0.6700
# Epoch 19/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6374 - recall: 0.6694 - val_loss: 0.6339 - val_recall: 0.6601
# Epoch 20/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6334 - recall: 0.6678 - val_loss: 0.6296 - val_recall: 0.6601
# Epoch 21/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6294 - recall: 0.6699 - val_loss: 0.6257 - val_recall: 0.6552
# Epoch 22/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6253 - recall: 0.6741 - val_loss: 0.6219 - val_recall: 0.6502
# Epoch 23/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6212 - recall: 0.6804 - val_loss: 0.6165 - val_recall: 0.6453
# Epoch 24/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6170 - recall: 0.6754 - val_loss: 0.6117 - val_recall: 0.6453
# Epoch 25/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6129 - recall: 0.6750 - val_loss: 0.6077 - val_recall: 0.6453
# Epoch 26/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6090 - recall: 0.6766 - val_loss: 0.6035 - val_recall: 0.6404
# Epoch 27/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6052 - recall: 0.6766 - val_loss: 0.5980 - val_recall: 0.6404
# Epoch 28/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6014 - recall: 0.6750 - val_loss: 0.5931 - val_recall: 0.6305
# Epoch 29/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5979 - recall: 0.6721 - val_loss: 0.5888 - val_recall: 0.6256
# Epoch 30/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5945 - recall: 0.6741 - val_loss: 0.5852 - val_recall: 0.6158
# Epoch 31/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5913 - recall: 0.6750 - val_loss: 0.5814 - val_recall: 0.6158
# Epoch 32/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5884 - recall: 0.6739 - val_loss: 0.5792 - val_recall: 0.6158
# Epoch 33/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5856 - recall: 0.6777 - val_loss: 0.5763 - val_recall: 0.6158
# Epoch 34/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5830 - recall: 0.6788 - val_loss: 0.5729 - val_recall: 0.6158
# Epoch 35/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5807 - recall: 0.6797 - val_loss: 0.5704 - val_recall: 0.6207
# Epoch 36/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5785 - recall: 0.6807 - val_loss: 0.5685 - val_recall: 0.6256
# Epoch 37/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5765 - recall: 0.6818 - val_loss: 0.5666 - val_recall: 0.6256
# Epoch 38/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5747 - recall: 0.6827 - val_loss: 0.5647 - val_recall: 0.6256
# Epoch 39/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5730 - recall: 0.6837 - val_loss: 0.5643 - val_recall: 0.6256
# Epoch 40/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5714 - recall: 0.6856 - val_loss: 0.5639 - val_recall: 0.6305
# Epoch 41/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5699 - recall: 0.6867 - val_loss: 0.5603 - val_recall: 0.6256
# Epoch 42/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5686 - recall: 0.6851 - val_loss: 0.5619 - val_recall: 0.6355
# Epoch 43/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5673 - recall: 0.6906 - val_loss: 0.5598 - val_recall: 0.6355
# Epoch 44/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5661 - recall: 0.6917 - val_loss: 0.5564 - val_recall: 0.6355
# Epoch 45/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5650 - recall: 0.6873 - val_loss: 0.5567 - val_recall: 0.6404
# Epoch 46/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5639 - recall: 0.6915 - val_loss: 0.5574 - val_recall: 0.6404
# Epoch 47/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5629 - recall: 0.6932 - val_loss: 0.5566 - val_recall: 0.6404
# Epoch 48/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5620 - recall: 0.6931 - val_loss: 0.5537 - val_recall: 0.6404
# Epoch 49/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5610 - recall: 0.6915 - val_loss: 0.5533 - val_recall: 0.6453
# Epoch 50/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5601 - recall: 0.6922 - val_loss: 0.5541 - val_recall: 0.6453
# Epoch 51/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5593 - recall: 0.6945 - val_loss: 0.5527 - val_recall: 0.6453
# Epoch 52/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5584 - recall: 0.6962 - val_loss: 0.5503 - val_recall: 0.6453
# Epoch 53/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5576 - recall: 0.6950 - val_loss: 0.5532 - val_recall: 0.6453
# Epoch 54/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5568 - recall: 0.6995 - val_loss: 0.5507 - val_recall: 0.6404
# Epoch 55/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5560 - recall: 0.6962 - val_loss: 0.5507 - val_recall: 0.6404
# Epoch 56/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5552 - recall: 0.6989 - val_loss: 0.5478 - val_recall: 0.6404
# Epoch 57/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5545 - recall: 0.6973 - val_loss: 0.5516 - val_recall: 0.6404
# Epoch 58/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5537 - recall: 0.7005 - val_loss: 0.5488 - val_recall: 0.6404
# Epoch 59/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5530 - recall: 0.7016 - val_loss: 0.5493 - val_recall: 0.6453
# Epoch 60/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5523 - recall: 0.7020 - val_loss: 0.5474 - val_recall: 0.6453
# Epoch 61/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5516 - recall: 0.6989 - val_loss: 0.5503 - val_recall: 0.6502
# Epoch 62/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5509 - recall: 0.7038 - val_loss: 0.5508 - val_recall: 0.6502
# Epoch 63/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5503 - recall: 0.7071 - val_loss: 0.5480 - val_recall: 0.6502
# Epoch 64/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5496 - recall: 0.7068 - val_loss: 0.5475 - val_recall: 0.6502
# Epoch 65/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5490 - recall: 0.7077 - val_loss: 0.5470 - val_recall: 0.6502
# Epoch 66/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5483 - recall: 0.7053 - val_loss: 0.5476 - val_recall: 0.6502
# Epoch 67/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5477 - recall: 0.7069 - val_loss: 0.5492 - val_recall: 0.6650
# Epoch 68/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5471 - recall: 0.7110 - val_loss: 0.5460 - val_recall: 0.6502
# Epoch 69/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5465 - recall: 0.7082 - val_loss: 0.5431 - val_recall: 0.6502
# Epoch 70/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5459 - recall: 0.7085 - val_loss: 0.5443 - val_recall: 0.6552
# Epoch 71/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5453 - recall: 0.7089 - val_loss: 0.5429 - val_recall: 0.6552
# Epoch 72/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5447 - recall: 0.7064 - val_loss: 0.5469 - val_recall: 0.6700
# Epoch 73/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5442 - recall: 0.7107 - val_loss: 0.5459 - val_recall: 0.6700
# Epoch 74/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5436 - recall: 0.7094 - val_loss: 0.5447 - val_recall: 0.6700
# Epoch 75/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5431 - recall: 0.7097 - val_loss: 0.5455 - val_recall: 0.6798
# Epoch 76/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5425 - recall: 0.7099 - val_loss: 0.5455 - val_recall: 0.6798
# Epoch 77/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5420 - recall: 0.7137 - val_loss: 0.5422 - val_recall: 0.6749
# Epoch 78/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5414 - recall: 0.7102 - val_loss: 0.5436 - val_recall: 0.6798
# Epoch 79/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5409 - recall: 0.7118 - val_loss: 0.5419 - val_recall: 0.6749
# Epoch 80/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5404 - recall: 0.7115 - val_loss: 0.5395 - val_recall: 0.6700
# Epoch 81/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5399 - recall: 0.7097 - val_loss: 0.5409 - val_recall: 0.6798
# Epoch 82/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5394 - recall: 0.7135 - val_loss: 0.5444 - val_recall: 0.6897
# Epoch 83/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5389 - recall: 0.7162 - val_loss: 0.5429 - val_recall: 0.6847
# Epoch 84/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5384 - recall: 0.7160 - val_loss: 0.5410 - val_recall: 0.6847
# Epoch 85/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5379 - recall: 0.7137 - val_loss: 0.5408 - val_recall: 0.6847
# Epoch 86/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5374 - recall: 0.7137 - val_loss: 0.5430 - val_recall: 0.6897
# Epoch 87/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5369 - recall: 0.7184 - val_loss: 0.5425 - val_recall: 0.6897
# Epoch 88/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5364 - recall: 0.7160 - val_loss: 0.5407 - val_recall: 0.6847
# Epoch 89/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5360 - recall: 0.7152 - val_loss: 0.5409 - val_recall: 0.6847
# Epoch 90/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5355 - recall: 0.7177 - val_loss: 0.5412 - val_recall: 0.6847
# Epoch 91/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5350 - recall: 0.7190 - val_loss: 0.5409 - val_recall: 0.6847
# Epoch 92/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5346 - recall: 0.7195 - val_loss: 0.5407 - val_recall: 0.6847
# Epoch 93/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5341 - recall: 0.7195 - val_loss: 0.5423 - val_recall: 0.6847
# Epoch 94/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5337 - recall: 0.7231 - val_loss: 0.5352 - val_recall: 0.6700
# Epoch 95/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5333 - recall: 0.7181 - val_loss: 0.5367 - val_recall: 0.6847
# Epoch 96/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5328 - recall: 0.7181 - val_loss: 0.5384 - val_recall: 0.6847
# Epoch 97/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5323 - recall: 0.7195 - val_loss: 0.5392 - val_recall: 0.6897
# Epoch 98/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5319 - recall: 0.7203 - val_loss: 0.5378 - val_recall: 0.6798
# Epoch 99/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5315 - recall: 0.7224 - val_loss: 0.5375 - val_recall: 0.6847
# Epoch 100/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5311 - recall: 0.7207 - val_loss: 0.5389 - val_recall: 0.6897

# %% [markdown]
# #### Loss

# %%
#Train Loss vs Validation Loss
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * Training and validation data are showing similar trends indicating the model is starting to generalize.
# * Model loss is high at .54.

# %% [markdown]
# #### Recall

# %%
#Train recall vs Validation recall
plt.plot(history_3.history['recall'])
plt.plot(history_3.history['val_recall'])
plt.title('model recall')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * Model diverges at 20 epoch.
# * The recall appears to be the highest, but still doesn't look like the model is generalized.

# %%
#Using .5 as the threshold on training
y_train_pred = model_3.predict(X_train_smote)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 399/399 [==============================] - 1s 2ms/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [False]])

# %%
#Using .5 as the threshold on training
y_val_pred = model_3.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 32/32 [==============================] - 0s 2ms/step
# array([[ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False]])

# %%
model_name = "Model 3 - Neural Network with SMOTE and Schocastic Gradient Descent"

train_metric_df.loc[model_name] = recall_score(y_train_smote,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# #### Classification Report

# %%
#Classification report
cr = classification_report(y_train_smote, y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.74      6370
#            1       0.74      0.72      0.73      6370
#
#     accuracy                           0.73     12740
#    macro avg       0.73      0.73      0.73     12740
# weighted avg       0.73      0.73      0.73     12740

# %%
#classification report
cr=classification_report(y_val, y_val_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.75      0.82       797
#            1       0.41      0.69      0.52       203
#
#     accuracy                           0.74      1000
#    macro avg       0.66      0.72      0.67      1000
# weighted avg       0.80      0.74      0.76      1000

# %% [markdown]
# ##### Observations
# * Recall is 72% for training and 69% for validation.
# * F1 is 73% and 52% respectively. It would be nice to bring these scores together.

# %% [markdown]
# #### Confusion Matrix

# %%
# Confusion matrix returned an error. 'Series' object has no attribute 'predict'
# make_confusion_matrix(y_train, y_train_pred)
# make_confusion_matrix(y_val,y_val_pred)

# %% [markdown]
# ### Model 4 - Neural Network with Balanced Data (by applying SMOTE) and Adam Optimizer
#
# * **SMOTE** applied to training set.
# * Neural Network
#   * Sequential
#   * Input Layer: 64 Nodes with Relu Activation
#   * Hidden Layer 1: 32 Nodes with Relu Activation
#   * Hidden Layer 2: 16 Nodes with Relu Activation
#   * Output Layer: 1 Node with Sigmoid Activation
# * Optimizer
#   * **Adam Optimizer**
#   * Metric tracked: Recall
# * Loss Function
#   * BinaryCrossEntropy
# * Training
#   * Batch Size: 64
#   * Epochs: 100

# %% [markdown]
# #### Add SMOTE to training set

# %%
sm  = SMOTE(random_state=42)
#Complete the code to fit SMOTE on the training data.
X_train_smote, y_train_smote= sm.fit_resample(X_train,y_train)
print('After UpSampling, the shape of train_X: {}'.format(X_train_smote.shape))
print('After UpSampling, the shape of train_y: {} \n'.format(y_train_smote.shape))
# Out:
# After UpSampling, the shape of train_X: (12740, 11)
# After UpSampling, the shape of train_y: (12740,)

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_4 = Sequential()
# Adding the input layer with 64 neurons and relu as activation function
model_4.add(Dense(64, activation='relu', input_dim = X_train.shape[1]))
# Adding 32 neuron to the hidden layer with relu activation function.
model_4.add(Dense(32, activation='relu'))
# Adding 16 neuron to the hidden layer with relu activation function.
model_4.add(Dense(16, activation='relu'))
# Since this is classification, we are using one output neuron and the Sigmoid activation function.
model_4.add(Dense(1, activation = 'sigmoid'))

# %%
#Schocastic Gradient Descent as the optimizer with a 0.001 learning rate.
optimizer = tf.keras.optimizers.Adam(0.001)

# We will be using recall to evaluate our model as we want to reduce the number of False Positives.
# That is customers we say are going to not leave the bank, but end up leaving.

metric = keras.metrics.Recall()
# metric = 'accuracy'
#metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# Use BinaryCrossEntropy as the loss function since this is a binary function.
losses = tf.keras.losses.BinaryCrossentropy()

# %%
# Compile the model
model_4.compile(loss=losses,optimizer=optimizer,metrics=[metric])

# %%
model_4.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 3393 (13.25 KB)
# Trainable params: 3393 (13.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fit the neural network
history_4 = model_4.fit(
    X_train_smote, y_train_smote,
    batch_size=64,
    epochs=100,
    verbose=1,
    validation_data = (X_val,y_val)
)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 2s 5ms/step - loss: 0.5708 - recall: 0.6958 - val_loss: 0.5034 - val_recall: 0.6650
# Epoch 2/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5025 - recall: 0.7399 - val_loss: 0.4910 - val_recall: 0.7143
# Epoch 3/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4699 - recall: 0.7716 - val_loss: 0.4287 - val_recall: 0.6207
# Epoch 4/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4515 - recall: 0.7750 - val_loss: 0.4881 - val_recall: 0.7685
# Epoch 5/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4331 - recall: 0.7998 - val_loss: 0.4434 - val_recall: 0.7143
# Epoch 6/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4198 - recall: 0.8053 - val_loss: 0.4501 - val_recall: 0.7143
# Epoch 7/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4112 - recall: 0.8119 - val_loss: 0.4195 - val_recall: 0.6897
# Epoch 8/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4015 - recall: 0.8187 - val_loss: 0.4307 - val_recall: 0.7094
# Epoch 9/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3965 - recall: 0.8239 - val_loss: 0.4715 - val_recall: 0.7488
# Epoch 10/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3912 - recall: 0.8242 - val_loss: 0.4218 - val_recall: 0.6749
# Epoch 11/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3868 - recall: 0.8251 - val_loss: 0.4459 - val_recall: 0.7044
# Epoch 12/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3826 - recall: 0.8295 - val_loss: 0.5109 - val_recall: 0.7586
# Epoch 13/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3773 - recall: 0.8316 - val_loss: 0.4815 - val_recall: 0.7291
# Epoch 14/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3777 - recall: 0.8319 - val_loss: 0.4394 - val_recall: 0.6897
# Epoch 15/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3729 - recall: 0.8383 - val_loss: 0.4280 - val_recall: 0.6847
# Epoch 16/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3700 - recall: 0.8374 - val_loss: 0.4508 - val_recall: 0.7143
# Epoch 17/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3660 - recall: 0.8436 - val_loss: 0.5004 - val_recall: 0.7340
# Epoch 18/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3654 - recall: 0.8400 - val_loss: 0.4702 - val_recall: 0.7241
# Epoch 19/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3653 - recall: 0.8341 - val_loss: 0.4328 - val_recall: 0.6847
# Epoch 20/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3578 - recall: 0.8487 - val_loss: 0.4371 - val_recall: 0.6700
# Epoch 21/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3526 - recall: 0.8504 - val_loss: 0.4648 - val_recall: 0.7094
# Epoch 22/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.3508 - recall: 0.8545 - val_loss: 0.5561 - val_recall: 0.7586
# Epoch 23/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.3503 - recall: 0.8529 - val_loss: 0.4600 - val_recall: 0.6946
# Epoch 24/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3446 - recall: 0.8527 - val_loss: 0.4832 - val_recall: 0.6847
# Epoch 25/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3425 - recall: 0.8548 - val_loss: 0.4518 - val_recall: 0.6650
# Epoch 26/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3403 - recall: 0.8557 - val_loss: 0.4649 - val_recall: 0.7094
# Epoch 27/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3369 - recall: 0.8571 - val_loss: 0.4993 - val_recall: 0.7143
# Epoch 28/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3335 - recall: 0.8575 - val_loss: 0.4560 - val_recall: 0.6552
# Epoch 29/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3316 - recall: 0.8576 - val_loss: 0.4410 - val_recall: 0.6305
# Epoch 30/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3303 - recall: 0.8576 - val_loss: 0.4658 - val_recall: 0.6700
# Epoch 31/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3276 - recall: 0.8611 - val_loss: 0.4489 - val_recall: 0.6650
# Epoch 32/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3246 - recall: 0.8642 - val_loss: 0.4606 - val_recall: 0.6749
# Epoch 33/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3192 - recall: 0.8689 - val_loss: 0.4688 - val_recall: 0.6749
# Epoch 34/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3191 - recall: 0.8688 - val_loss: 0.4760 - val_recall: 0.6601
# Epoch 35/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3179 - recall: 0.8673 - val_loss: 0.4761 - val_recall: 0.6847
# Epoch 36/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3149 - recall: 0.8700 - val_loss: 0.4703 - val_recall: 0.6404
# Epoch 37/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.3154 - recall: 0.8714 - val_loss: 0.4455 - val_recall: 0.6158
# Epoch 38/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3131 - recall: 0.8694 - val_loss: 0.4585 - val_recall: 0.6404
# Epoch 39/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3102 - recall: 0.8703 - val_loss: 0.4753 - val_recall: 0.6552
# Epoch 40/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3089 - recall: 0.8747 - val_loss: 0.4842 - val_recall: 0.6552
# Epoch 41/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3080 - recall: 0.8747 - val_loss: 0.4681 - val_recall: 0.6355
# Epoch 42/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3018 - recall: 0.8782 - val_loss: 0.5482 - val_recall: 0.7094
# Epoch 43/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3035 - recall: 0.8736 - val_loss: 0.5463 - val_recall: 0.6897
# Epoch 44/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3023 - recall: 0.8776 - val_loss: 0.4588 - val_recall: 0.6158
# Epoch 45/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2984 - recall: 0.8791 - val_loss: 0.4976 - val_recall: 0.6502
# Epoch 46/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2998 - recall: 0.8750 - val_loss: 0.5156 - val_recall: 0.6700
# Epoch 47/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2960 - recall: 0.8790 - val_loss: 0.4819 - val_recall: 0.6256
# Epoch 48/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2932 - recall: 0.8804 - val_loss: 0.4817 - val_recall: 0.6158
# Epoch 49/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2900 - recall: 0.8824 - val_loss: 0.4579 - val_recall: 0.6207
# Epoch 50/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.2908 - recall: 0.8794 - val_loss: 0.4874 - val_recall: 0.6355
# Epoch 51/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.2868 - recall: 0.8837 - val_loss: 0.4558 - val_recall: 0.5862
# Epoch 52/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.2902 - recall: 0.8749 - val_loss: 0.4957 - val_recall: 0.6355
# Epoch 53/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2940 - recall: 0.8774 - val_loss: 0.4757 - val_recall: 0.5862
# Epoch 54/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2811 - recall: 0.8873 - val_loss: 0.4872 - val_recall: 0.6010
# Epoch 55/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2787 - recall: 0.8890 - val_loss: 0.4767 - val_recall: 0.5862
# Epoch 56/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2798 - recall: 0.8901 - val_loss: 0.5160 - val_recall: 0.6158
# Epoch 57/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2765 - recall: 0.8914 - val_loss: 0.5699 - val_recall: 0.6798
# Epoch 58/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2779 - recall: 0.8940 - val_loss: 0.4979 - val_recall: 0.6305
# Epoch 59/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2721 - recall: 0.8914 - val_loss: 0.4868 - val_recall: 0.5911
# Epoch 60/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2771 - recall: 0.8890 - val_loss: 0.5275 - val_recall: 0.6798
# Epoch 61/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2720 - recall: 0.8928 - val_loss: 0.5696 - val_recall: 0.6798
# Epoch 62/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2727 - recall: 0.8911 - val_loss: 0.5828 - val_recall: 0.6847
# Epoch 63/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2697 - recall: 0.8929 - val_loss: 0.5333 - val_recall: 0.6207
# Epoch 64/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2682 - recall: 0.8958 - val_loss: 0.5385 - val_recall: 0.6108
# Epoch 65/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.2664 - recall: 0.8943 - val_loss: 0.5157 - val_recall: 0.5911
# Epoch 66/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.2637 - recall: 0.8969 - val_loss: 0.5625 - val_recall: 0.6601
# Epoch 67/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2638 - recall: 0.8972 - val_loss: 0.5299 - val_recall: 0.6158
# Epoch 68/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2616 - recall: 0.8969 - val_loss: 0.5144 - val_recall: 0.5911
# Epoch 69/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2599 - recall: 0.8995 - val_loss: 0.5186 - val_recall: 0.6010
# Epoch 70/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2654 - recall: 0.8911 - val_loss: 0.5773 - val_recall: 0.6355
# Epoch 71/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2585 - recall: 0.8980 - val_loss: 0.5000 - val_recall: 0.5271
# Epoch 72/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2571 - recall: 0.8981 - val_loss: 0.6943 - val_recall: 0.7044
# Epoch 73/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2586 - recall: 0.8981 - val_loss: 0.5543 - val_recall: 0.6256
# Epoch 74/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2524 - recall: 0.9052 - val_loss: 0.5232 - val_recall: 0.5813
# Epoch 75/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2556 - recall: 0.8997 - val_loss: 0.5383 - val_recall: 0.6059
# Epoch 76/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2534 - recall: 0.9036 - val_loss: 0.5527 - val_recall: 0.6010
# Epoch 77/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2513 - recall: 0.9022 - val_loss: 0.5281 - val_recall: 0.5714
# Epoch 78/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2512 - recall: 0.9044 - val_loss: 0.5378 - val_recall: 0.5911
# Epoch 79/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.2517 - recall: 0.9020 - val_loss: 0.5296 - val_recall: 0.5616
# Epoch 80/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.2466 - recall: 0.9020 - val_loss: 0.5394 - val_recall: 0.5714
# Epoch 81/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2542 - recall: 0.8986 - val_loss: 0.5510 - val_recall: 0.5764
# Epoch 82/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2442 - recall: 0.9035 - val_loss: 0.5488 - val_recall: 0.5862
# Epoch 83/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2463 - recall: 0.9078 - val_loss: 0.5476 - val_recall: 0.5813
# Epoch 84/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2427 - recall: 0.9063 - val_loss: 0.5670 - val_recall: 0.5862
# Epoch 85/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2440 - recall: 0.9068 - val_loss: 0.5794 - val_recall: 0.6059
# Epoch 86/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2436 - recall: 0.9028 - val_loss: 0.5993 - val_recall: 0.6305
# Epoch 87/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2385 - recall: 0.9083 - val_loss: 0.6238 - val_recall: 0.6355
# Epoch 88/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2429 - recall: 0.9038 - val_loss: 0.5999 - val_recall: 0.6158
# Epoch 89/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2373 - recall: 0.9089 - val_loss: 0.6139 - val_recall: 0.6453
# Epoch 90/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2392 - recall: 0.9085 - val_loss: 0.5988 - val_recall: 0.6059
# Epoch 91/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2371 - recall: 0.9097 - val_loss: 0.6133 - val_recall: 0.6404
# Epoch 92/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2348 - recall: 0.9066 - val_loss: 0.6263 - val_recall: 0.6256
# Epoch 93/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.2352 - recall: 0.9118 - val_loss: 0.5945 - val_recall: 0.5961
# Epoch 94/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.2374 - recall: 0.9077 - val_loss: 0.5656 - val_recall: 0.5074
# Epoch 95/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2446 - recall: 0.9049 - val_loss: 0.5689 - val_recall: 0.5911
# Epoch 96/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2341 - recall: 0.9105 - val_loss: 0.6172 - val_recall: 0.6355
# Epoch 97/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2365 - recall: 0.9074 - val_loss: 0.6306 - val_recall: 0.6256
# Epoch 98/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2304 - recall: 0.9141 - val_loss: 0.5809 - val_recall: 0.6010
# Epoch 99/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2351 - recall: 0.9097 - val_loss: 0.6191 - val_recall: 0.6256
# Epoch 100/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2266 - recall: 0.9143 - val_loss: 0.5983 - val_recall: 0.6108

# %% [markdown]
# #### Loss

# %%
#Train Loss vs Validation Loss
plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * Model loss on training data is the lowest yet, however, validation data loss is very bad showing signs of overfitting.

# %% [markdown]
# #### Recall

# %%
#Train recall vs Validation recall
plt.plot(history_4.history['recall'])
plt.plot(history_4.history['val_recall'])
plt.title('model recall')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * Model diverges immediately.
# * The recall appears to be the highest for training, but is overfit because validation data is diverging immediately.

# %%
#Using .5 as the threshold on training
y_train_pred = model_4.predict(X_train_smote)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 399/399 [==============================] - 1s 2ms/step
# array([[ True],
#        [ True],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
#Using .5 as the threshold on training
y_val_pred = model_4.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 32/32 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False]])

# %%
model_name = "Model 4 - Neural Network with SMOTE and Adam"

train_metric_df.loc[model_name] = recall_score(y_train_smote,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# #### Classification Report

# %%
#Classification report
cr = classification_report(y_train_smote, y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91      6370
#            1       0.91      0.90      0.91      6370
#
#     accuracy                           0.91     12740
#    macro avg       0.91      0.91      0.91     12740
# weighted avg       0.91      0.91      0.91     12740

# %%
#classification report
cr=classification_report(y_val, y_val_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.87       797
#            1       0.50      0.61      0.55       203
#
#     accuracy                           0.80      1000
#    macro avg       0.70      0.73      0.71      1000
# weighted avg       0.81      0.80      0.80      1000

# %% [markdown]
# ##### Observations
# * Recall is 90% for training and 58% for validation.
# * F1 is 90% and 53% respectively.
# * Model overall looks overfit.

# %% [markdown]
# #### Confusion Matrix

# %%
# Confusion matrix returned an error. 'Series' object has no attribute 'predict'
# make_confusion_matrix(y_train, y_train_pred)
# make_confusion_matrix(y_val,y_val_pred)

# %% [markdown]
# ### Model 5 - Neural Network with Balanced Data (by applying SMOTE), Adam Optimizer, and Dropout
#
# * **SMOTE** applied to training set.
# * Neural Network
#   * Sequential
#   * Input Layer: 64 Nodes with Relu Activation
#   * **Dropout** with rate of .6.
#   * Hidden Layer 1: 32 Nodes with Relu Activation
#   * **Dropout** with a rate of .6.
#   * Hidden Layer 2: 16 Nodes with Relu Activation
#   * Output Layer: 1 Node with Sigmoid Activation
# * Optimizer
#   * **Adam Optimizer**
#   * Metric tracked: Recall
# * Loss Function
#   * BinaryCrossEntropy
# * Training
#   * Batch Size: 64
#   * Epochs: 100

# %% [markdown]
# #### Add SMOTE to training set

# %%
sm  = SMOTE(random_state=42)
#Complete the code to fit SMOTE on the training data.
X_train_smote, y_train_smote= sm.fit_resample(X_train,y_train)
print('After UpSampling, the shape of train_X: {}'.format(X_train_smote.shape))
print('After UpSampling, the shape of train_y: {} \n'.format(y_train_smote.shape))
# Out:
# After UpSampling, the shape of train_X: (12740, 11)
# After UpSampling, the shape of train_y: (12740,)

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_5 = Sequential()
# Adding the input layer with 64 neurons and relu as activation function
model_5.add(Dense(64, activation='relu', input_dim = X_train.shape[1]))
# Adding dropout with rate of .8
model_5.add(Dropout(0.6))
# Adding 32 neuron to the hidden layer with relu activation function.
model_5.add(Dense(32, activation='relu'))
# Adding dropout with rate of .6
model_5.add(Dropout(0.6))
# Adding 16 neuron to the hidden layer with relu activation function.
model_5.add(Dense(16, activation='relu'))
# Since this is classification, we are using one output neuron and the Sigmoid activation function.
model_5.add(Dense(1, activation = 'sigmoid'))

# %%
#Schocastic Gradient Descent as the optimizer with a 0.001 learning rate.
optimizer = tf.keras.optimizers.Adam(0.001)

# We will be using recall to evaluate our model as we want to reduce the number of False Positives.
# That is customers we say are going to not leave the bank, but end up leaving.

metric = keras.metrics.Recall()
# metric = 'accuracy'
#metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# Use BinaryCrossEntropy as the loss function since this is a binary function.
losses = tf.keras.losses.BinaryCrossentropy()

# %%
# Compile the model
model_5.compile(loss=losses,optimizer=optimizer,metrics=[metric])

# %%
model_5.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                768
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_2 (Dense)             (None, 16)                528
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 3393 (13.25 KB)
# Trainable params: 3393 (13.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Fit the neural network
history_5 = model_5.fit(
    X_train_smote, y_train_smote,
    batch_size=64,
    epochs=100,
    verbose=1,
    validation_data = (X_val,y_val)
)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 2s 5ms/step - loss: 0.6655 - recall: 0.5841 - val_loss: 0.5679 - val_recall: 0.6355
# Epoch 2/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6073 - recall: 0.6766 - val_loss: 0.5502 - val_recall: 0.6700
# Epoch 3/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5873 - recall: 0.7074 - val_loss: 0.5738 - val_recall: 0.7094
# Epoch 4/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5754 - recall: 0.7094 - val_loss: 0.5675 - val_recall: 0.6946
# Epoch 5/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5635 - recall: 0.7177 - val_loss: 0.5663 - val_recall: 0.6650
# Epoch 6/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5562 - recall: 0.7008 - val_loss: 0.5547 - val_recall: 0.6601
# Epoch 7/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5467 - recall: 0.7168 - val_loss: 0.5544 - val_recall: 0.6502
# Epoch 8/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5410 - recall: 0.7143 - val_loss: 0.5539 - val_recall: 0.6404
# Epoch 9/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5361 - recall: 0.7157 - val_loss: 0.5667 - val_recall: 0.6502
# Epoch 10/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5299 - recall: 0.7144 - val_loss: 0.5607 - val_recall: 0.6404
# Epoch 11/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5257 - recall: 0.7080 - val_loss: 0.5477 - val_recall: 0.6404
# Epoch 12/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5222 - recall: 0.7220 - val_loss: 0.5536 - val_recall: 0.6502
# Epoch 13/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5189 - recall: 0.7292 - val_loss: 0.5378 - val_recall: 0.6552
# Epoch 14/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5131 - recall: 0.7300 - val_loss: 0.5171 - val_recall: 0.6700
# Epoch 15/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5088 - recall: 0.7317 - val_loss: 0.5204 - val_recall: 0.6650
# Epoch 16/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.5039 - recall: 0.7342 - val_loss: 0.5218 - val_recall: 0.6847
# Epoch 17/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5026 - recall: 0.7327 - val_loss: 0.5234 - val_recall: 0.6946
# Epoch 18/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.5021 - recall: 0.7433 - val_loss: 0.5066 - val_recall: 0.6847
# Epoch 19/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4881 - recall: 0.7523 - val_loss: 0.5022 - val_recall: 0.6847
# Epoch 20/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4932 - recall: 0.7542 - val_loss: 0.4997 - val_recall: 0.7192
# Epoch 21/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4902 - recall: 0.7520 - val_loss: 0.4782 - val_recall: 0.7094
# Epoch 22/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4843 - recall: 0.7617 - val_loss: 0.5043 - val_recall: 0.7389
# Epoch 23/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4799 - recall: 0.7686 - val_loss: 0.4769 - val_recall: 0.7438
# Epoch 24/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4812 - recall: 0.7692 - val_loss: 0.4684 - val_recall: 0.7340
# Epoch 25/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4788 - recall: 0.7705 - val_loss: 0.4661 - val_recall: 0.7488
# Epoch 26/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4714 - recall: 0.7711 - val_loss: 0.4655 - val_recall: 0.7340
# Epoch 27/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4671 - recall: 0.7815 - val_loss: 0.4557 - val_recall: 0.7192
# Epoch 28/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4699 - recall: 0.7702 - val_loss: 0.4528 - val_recall: 0.7094
# Epoch 29/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4651 - recall: 0.7774 - val_loss: 0.4727 - val_recall: 0.7488
# Epoch 30/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4650 - recall: 0.7779 - val_loss: 0.4545 - val_recall: 0.7291
# Epoch 31/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4573 - recall: 0.7884 - val_loss: 0.4504 - val_recall: 0.7488
# Epoch 32/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4581 - recall: 0.7898 - val_loss: 0.4643 - val_recall: 0.7586
# Epoch 33/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4574 - recall: 0.7962 - val_loss: 0.4517 - val_recall: 0.7685
# Epoch 34/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4555 - recall: 0.7923 - val_loss: 0.4481 - val_recall: 0.7488
# Epoch 35/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4606 - recall: 0.7835 - val_loss: 0.4616 - val_recall: 0.7783
# Epoch 36/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4552 - recall: 0.7896 - val_loss: 0.4543 - val_recall: 0.7438
# Epoch 37/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4516 - recall: 0.8002 - val_loss: 0.4531 - val_recall: 0.7537
# Epoch 38/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4451 - recall: 0.8044 - val_loss: 0.4405 - val_recall: 0.7586
# Epoch 39/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4532 - recall: 0.7931 - val_loss: 0.4417 - val_recall: 0.7143
# Epoch 40/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4497 - recall: 0.7943 - val_loss: 0.4319 - val_recall: 0.7438
# Epoch 41/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4487 - recall: 0.8044 - val_loss: 0.4378 - val_recall: 0.7635
# Epoch 42/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4489 - recall: 0.7928 - val_loss: 0.4554 - val_recall: 0.7685
# Epoch 43/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4472 - recall: 0.8002 - val_loss: 0.4325 - val_recall: 0.7537
# Epoch 44/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4461 - recall: 0.7964 - val_loss: 0.4339 - val_recall: 0.7438
# Epoch 45/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4427 - recall: 0.8019 - val_loss: 0.4415 - val_recall: 0.7537
# Epoch 46/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4482 - recall: 0.7843 - val_loss: 0.4336 - val_recall: 0.7143
# Epoch 47/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4421 - recall: 0.7890 - val_loss: 0.4251 - val_recall: 0.7044
# Epoch 48/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4427 - recall: 0.7865 - val_loss: 0.4312 - val_recall: 0.7143
# Epoch 49/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4388 - recall: 0.7961 - val_loss: 0.4463 - val_recall: 0.7635
# Epoch 50/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4466 - recall: 0.7915 - val_loss: 0.4403 - val_recall: 0.7438
# Epoch 51/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4431 - recall: 0.8035 - val_loss: 0.4378 - val_recall: 0.7685
# Epoch 52/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4428 - recall: 0.8060 - val_loss: 0.4310 - val_recall: 0.7635
# Epoch 53/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4428 - recall: 0.7934 - val_loss: 0.4396 - val_recall: 0.7734
# Epoch 54/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4404 - recall: 0.7969 - val_loss: 0.4332 - val_recall: 0.7094
# Epoch 55/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4425 - recall: 0.8016 - val_loss: 0.4462 - val_recall: 0.7488
# Epoch 56/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4462 - recall: 0.7777 - val_loss: 0.4366 - val_recall: 0.7094
# Epoch 57/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4389 - recall: 0.7807 - val_loss: 0.4430 - val_recall: 0.7340
# Epoch 58/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4412 - recall: 0.7965 - val_loss: 0.4394 - val_recall: 0.7340
# Epoch 59/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4388 - recall: 0.7959 - val_loss: 0.4130 - val_recall: 0.6847
# Epoch 60/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4385 - recall: 0.7843 - val_loss: 0.4225 - val_recall: 0.6995
# Epoch 61/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4339 - recall: 0.8066 - val_loss: 0.4482 - val_recall: 0.7685
# Epoch 62/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4409 - recall: 0.8088 - val_loss: 0.4537 - val_recall: 0.7931
# Epoch 63/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4378 - recall: 0.8181 - val_loss: 0.4386 - val_recall: 0.7734
# Epoch 64/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4386 - recall: 0.8005 - val_loss: 0.4316 - val_recall: 0.7143
# Epoch 65/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4379 - recall: 0.7904 - val_loss: 0.4324 - val_recall: 0.7143
# Epoch 66/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4366 - recall: 0.7838 - val_loss: 0.4450 - val_recall: 0.7291
# Epoch 67/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4330 - recall: 0.7911 - val_loss: 0.4351 - val_recall: 0.7192
# Epoch 68/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4376 - recall: 0.7981 - val_loss: 0.4292 - val_recall: 0.7192
# Epoch 69/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4380 - recall: 0.7804 - val_loss: 0.4214 - val_recall: 0.6995
# Epoch 70/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4367 - recall: 0.7841 - val_loss: 0.4284 - val_recall: 0.7044
# Epoch 71/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4368 - recall: 0.7911 - val_loss: 0.4305 - val_recall: 0.7143
# Epoch 72/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4359 - recall: 0.7845 - val_loss: 0.4418 - val_recall: 0.7192
# Epoch 73/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4386 - recall: 0.7904 - val_loss: 0.4311 - val_recall: 0.6995
# Epoch 74/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4376 - recall: 0.7783 - val_loss: 0.4575 - val_recall: 0.7340
# Epoch 75/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4370 - recall: 0.7873 - val_loss: 0.4257 - val_recall: 0.7340
# Epoch 76/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4329 - recall: 0.7849 - val_loss: 0.4377 - val_recall: 0.7389
# Epoch 77/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4333 - recall: 0.7950 - val_loss: 0.4199 - val_recall: 0.7192
# Epoch 78/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4351 - recall: 0.7862 - val_loss: 0.4292 - val_recall: 0.7192
# Epoch 79/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4341 - recall: 0.7912 - val_loss: 0.4258 - val_recall: 0.7340
# Epoch 80/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4385 - recall: 0.7901 - val_loss: 0.4250 - val_recall: 0.7094
# Epoch 81/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4322 - recall: 0.7879 - val_loss: 0.4154 - val_recall: 0.7143
# Epoch 82/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4336 - recall: 0.7989 - val_loss: 0.4330 - val_recall: 0.7192
# Epoch 83/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4313 - recall: 0.7906 - val_loss: 0.4254 - val_recall: 0.7192
# Epoch 84/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4337 - recall: 0.7860 - val_loss: 0.4295 - val_recall: 0.7094
# Epoch 85/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4343 - recall: 0.7885 - val_loss: 0.4370 - val_recall: 0.7143
# Epoch 86/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4338 - recall: 0.7862 - val_loss: 0.4277 - val_recall: 0.7094
# Epoch 87/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4370 - recall: 0.7922 - val_loss: 0.4424 - val_recall: 0.7685
# Epoch 88/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4316 - recall: 0.8174 - val_loss: 0.4286 - val_recall: 0.7586
# Epoch 89/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4353 - recall: 0.8204 - val_loss: 0.4384 - val_recall: 0.7586
# Epoch 90/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4361 - recall: 0.8184 - val_loss: 0.4341 - val_recall: 0.7586
# Epoch 91/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4329 - recall: 0.8181 - val_loss: 0.4277 - val_recall: 0.7488
# Epoch 92/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4327 - recall: 0.8078 - val_loss: 0.4386 - val_recall: 0.7882
# Epoch 93/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4324 - recall: 0.8215 - val_loss: 0.4326 - val_recall: 0.7488
# Epoch 94/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4364 - recall: 0.8284 - val_loss: 0.4260 - val_recall: 0.7389
# Epoch 95/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4317 - recall: 0.8204 - val_loss: 0.4225 - val_recall: 0.7389
# Epoch 96/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4341 - recall: 0.8192 - val_loss: 0.4347 - val_recall: 0.7389
# Epoch 97/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4287 - recall: 0.8246 - val_loss: 0.4418 - val_recall: 0.7537
# Epoch 98/100
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4304 - recall: 0.8089 - val_loss: 0.4231 - val_recall: 0.7241
# Epoch 99/100
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4288 - recall: 0.8133 - val_loss: 0.4328 - val_recall: 0.7586
# Epoch 100/100
# 200/200 [==============================] - 1s 6ms/step - loss: 0.4339 - recall: 0.7926 - val_loss: 0.4215 - val_recall: 0.7094

# %% [markdown]
# #### Loss

# %%
#Train Loss vs Validation Loss
plt.plot(history_5.history['loss'])
plt.plot(history_5.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * Model loss on training data is the lowest yet, however, validation data loss is very bad showing signs of overfitting.

# %% [markdown]
# #### Recall

# %%
#Train recall vs Validation recall
plt.plot(history_5.history['recall'])
plt.plot(history_5.history['val_recall'])
plt.title('model recall')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# ##### Observations
# * Model diverges immediately.
# * The recall appears to be the highest for training, but is overfit because validation data is diverging immediately.

# %%
#Using .5 as the threshold on training
y_train_pred = model_5.predict(X_train_smote)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 399/399 [==============================] - 1s 2ms/step
# array([[ True],
#        [ True],
#        [False],
#        ...,
#        [ True],
#        [ True],
#        [ True]])

# %%
#Using .5 as the threshold on training
y_val_pred = model_5.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 32/32 [==============================] - 0s 2ms/step
# array([[False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True]])

# %%
y_test_pred = model_5.predict(X_test)    ## Complete the code to specify the best model
y_test_pred = (y_test_pred > 0.5)
print(y_test_pred)
# Out:
# 32/32 [==============================] - 0s 2ms/step
# [[ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [ True]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [ True]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]
#  [False]]

# %%
model_name = "Model 5 = Neural Network with SMOTE, Adam and Dropout"

train_metric_df.loc[model_name] = recall_score(y_train_smote,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# #### Classification Report

# %%
#Classification report
cr = classification_report(y_train_smote, y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83      6370
#            1       0.84      0.81      0.82      6370
#
#     accuracy                           0.83     12740
#    macro avg       0.83      0.83      0.83     12740
# weighted avg       0.83      0.83      0.83     12740

# %%
#classification report
cr=classification_report(y_val, y_val_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.87       797
#            1       0.50      0.71      0.59       203
#
#     accuracy                           0.80      1000
#    macro avg       0.71      0.76      0.73      1000
# weighted avg       0.83      0.80      0.81      1000

# %%
#lets print classification report
cr=classification_report(y_test,y_test_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.82      0.86       796
#            1       0.49      0.71      0.58       204
#
#     accuracy                           0.79      1000
#    macro avg       0.71      0.76      0.72      1000
# weighted avg       0.83      0.79      0.81      1000

# %% [markdown]
# ##### Observations
# * Recall is 81% for training and 73% for validation.
# * Recall is 71% on test data.
# * F1 score is good for training at 82%, but falls off to 60% and 59% respectively for validation and test.
#
# **Recall is the dominate metric we are tracking so these results overall are good.**

# %% [markdown]
# #### Confusion Matrix

# %%
# Confusion matrix returned an error. 'Series' object has no attribute 'predict'
# make_confusion_matrix(y_train, y_train_pred)
# make_confusion_matrix(y_val,y_val_pred)

# %% [markdown]
# ## Model Performance Comparison and Final Model Selection

# %% [markdown]
# ### Training Metrics for Six Models.

# %%
print("Training performance comparison")
train_metric_df
# Out:
# Training performance comparison
#                                                       recall
# Model 0 - Neural Network with Schocastic Gradie...  0.150920
# Model 1 - Neural Network with Adam Optimizer        0.590798
# Model 2 - Neural Network with Adam Optimizer an...  0.544172
# Model 3 - Neural Network with SMOTE and Schocas...  0.722920
# Model 4 - Neural Network with SMOTE and Adam        0.899686
# Model 5 = Neural Network with SMOTE, Adam and D...  0.810047

# %% [markdown]
# #### Observations Training
# * Model 4 was the best trained model. Model 5 was second and Model 3 was third.
# * All three of these models should be considered based on test and validation data.

# %%
print("Validation set performance comparison")
valid_metric_df
# Out:
# Validation set performance comparison
#                                                       recall
# Model 0 - Neural Network with Schocastic Gradie...  0.103448
# Model 1 - Neural Network with Adam Optimizer        0.527094
# Model 2 - Neural Network with Adam Optimizer an...  0.458128
# Model 3 - Neural Network with SMOTE and Schocas...  0.689655
# Model 4 - Neural Network with SMOTE and Adam        0.610837
# Model 5 = Neural Network with SMOTE, Adam and D...  0.709360

# %% [markdown]
# #### Observations Validation
# * Model 5 was the best performing model on validation data followed by model 3.
# * Model 4 had 58% recals which isn't great compared to its training recall of 89%.

# %% [markdown]
# ### Compare Difference in Recall for Train and Validation

# %%
train_metric_df - valid_metric_df
# Out:
#                                                       recall
# Model 0 - Neural Network with Schocastic Gradie...  0.047472
# Model 1 - Neural Network with Adam Optimizer        0.063704
# Model 2 - Neural Network with Adam Optimizer an...  0.086044
# Model 3 - Neural Network with SMOTE and Schocas...  0.033265
# Model 4 - Neural Network with SMOTE and Adam        0.288849
# Model 5 = Neural Network with SMOTE, Adam and D...  0.100687

# %% [markdown]
# #### Observations
# * Model 3 was the most generalized mode having a difference in recall of only 3%.
# * Model 5 was second with a recall of 8%
# * Model 4 should be excluded because its recall difference was 31%. The worst of all the model.

# %% [markdown]
# ### Final Model Observations
#
# **Model 5 performed the best overall so that is the model I would use an optimize.**
#
# **Second was Model 3, but the Recall of about 70% is not as good as Model 5.**

# %% [markdown]
# #### Confusion Matrix

# %%
# Confusion matrix returned an error. 'Series' object has no attribute 'predict'
# make_confusion_matrix(y_train, y_train_pred)
# make_confusion_matrix(y_val,y_val_pred)

# %% [markdown]
# ## Actionable Insights and Business Recommendations

# %% [markdown]
# ### 1. Targeted Engagement for Low-Balance Customers:
#    - **Actionable Insight:** Customers with zero balance may be at risk of churning due to lack of activity.
#    - **Business Recommendation:** Implement targeted outreach campaigns to understand reasons behind zero balance accounts and offer deposit incentives to encourage positive balances.

# %% [markdown]
# ### 2. Customized Retention Strategies for High-Product Customers:
#    - **Actionable Insight:** Customers with more than two products exhibit higher churn rates.
#    - **Business Recommendation:** Develop retention strategies tailored to address the specific needs and preferences of customers with multiple products. The aim is to improve product satisfaction and loyalty. Consider streamlining product offerings to avoid confusion which may be turning off some customers.

# %% [markdown]
# ### 3. Credit Card Utilization Enhancement:
#    - **Actionable Insight:** Low credit card utilization may indicate disengagement with banking services.
#    - **Business Recommendation:** Promote increased credit card usage through tailored benefits and rewards. Encourage activity to reducing churn risk.
#
# ### 4. Reactivation Campaigns for Inactive Members:
#    - **Actionable Insight:** Inactive customers represent a significant churn risk.
#    - **Business Recommendation:** Launch targeted reactivation campaigns offering incentives to encourage inactive customers to re-engage with bank services.

# %% [markdown]
# ### 5. Age-Specific Retention Initiatives for Older Customers:
#    - **Actionable Insight:** Customers aged 40-50 demonstrate higher churn rates. Additionally, older demographics may require enhanced support and simplified processes.
#    - **Business Recommendation:** Develop age-specific retention initiatives tailored to address the needs and preferences of older customers. For example, streamline banking processes to simplify the customer experience for older demographics.

# %% [markdown]
# ### 6. Continuous Monitoring and Adjustment:
#    - **Actionable Insight:** Customer behavior and preferences may evolve over time, impacting churn rates.
#    - **Business Recommendation:** Continuously monitor customer feedback and market dynamics to identify early signs of churn and adapt retention strategies to effectively mitigate churn risks.
